# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ### Caucus data

# %%
caucuses = pd.read_csv("data/data_archive/caucuses_117congress.csv")

# %%
progressive = [member for member in list(caucuses["Progressive Caucus"]) if type(member) == str]
new_democratic = [member for member in list(caucuses["New Democratic Coalition"]) if type(member) == str]
freedom = [member for member in list(caucuses["Freedom Caucus"]) if type(member) == str]
rep_gov_group = [member for member in list(caucuses["Republican Governance Group"]) if type(member) == str]
rep_study_committee = [member for member in list(caucuses["Republican Study Committee"]) if type(member) == str]
problem_solvers = [member for member in list(caucuses["Problem Solvers Caucus"]) if type(member) == str]

# %%
for item in [progressive, new_democratic, freedom, rep_gov_group, rep_study_committee, problem_solvers]:
    for i in range(len(item)):
            item[i] = item[i].strip()

# %%
data = {"Progressive Caucus":progressive, 
        "New Democratic Coalition":new_democratic,
        "Freedom Caucus":freedom,
        "Republican Governance Group":rep_gov_group,
        "Republican Study Committee":rep_study_committee,
        "Problem Solvers Caucus":problem_solvers}

# %%
with open("data/caucus_117.json", "w") as file:
    json.dump(data, file)

# %% [markdown]
# ### Members and Usernames

# %%
members = pd.read_csv("data/data_archive/117congress_members.csv")
members.head()
# Out:
#          First      Last           State       Party
# 0     Alma S.      Adams  North Carolina  Democratic
# 1   Robert B.   Aderholt         Alabama  Republican
# 2        Pete    Aguilar      California  Democratic
# 3     Rick W.      Allen         Georgia  Republican
# 4    Colin Z.     Allred           Texas  Democratic

# %%
usernames = pd.read_csv("data/data_archive/workbook_XMembers.csv")[["Last Name", "First Name", "Handle", "Handle.1"]]
usernames.head()
# Out:
#     Last Name First Name          Handle   Handle.1
# 0   Murkowski       Lisa   lisamurkowski        NaN
# 1    Sullivan        Dan  SenDanSullivan        NaN
# 2      Shelby    Richard              C.  SenShelby
# 3  Tuberville      Tommy   SenTuberville        NaN
# 4     Boozman       John     JohnBoozman        NaN

# %%
last_names = usernames["Last Name"]
first_names = usernames["First Name"]
handles1 = usernames["Handle"]
handles2 = usernames["Handle.1"]

# %%
actual_handles = []
full_names = []

for i in range(len(handles1)):
    if type(handles2[i]) == float:
        actual_handles += [handles1[i]]
        full_names += [(first_names[i] + " " + last_names[i])]
    else:
        actual_handles += [handles2[i]]
        full_names += [(first_names[i] + " " + last_names[i])]

# %%
data = {"name":full_names,
        "username":actual_handles}

# %%
data
# Out:
# {'name': ['Lisa Murkowski',
#   'Dan Sullivan',
#   'Richard Shelby',
#   'Tommy Tuberville',
#   'John Boozman',
#   'Tom Cotton',
#   'Mark Kelly',
#   'Kyrsten Sinema',
#   'Dianne Feinstein',
#   'Alex Padilla',
#   'Michael Bennet',
#   'John Hickenlooper',
#   'Richard Blumenthal',
#   'Christopher Murphy',
#   'Thomas Carper',
#   'Christopher Coons',
#   'Marco Rubio',
#   'Rick Scott',
#   'Jon Ossoff',
#   'Raphael Warnock',
#   'Mazie Hirono',
#   'Brian Schatz',
#   'Joni Ernst',
#   'Chuck Grassley',
#   'Mike Crapo',
#   'James Risch',
#   'Tammy Duckworth',
#   'Richard Durbin',
#   'Mike Braun',
#   'Todd Young',
#   'Roger Marshall',
#   'Jerry Moran',
#   'Mitch McConnell',
#   'Rand Paul',
#   'Bill Cassidy',
#   'John Kennedy',
#   'Edward Markey',
#   'Elizabeth Warren',
#   'Benjamin Cardin',
#   'Chris Van Hollen',
#   'Susan Collins',
#   'Angus King',
#   'Gary Peters',
#   'Debbie Stabenow',
#   'Amy Klobuchar',
#   'Tina Smith',
#   'Roy Blunt',
#   'Josh Hawley',
#   'Cindy Hyde-Smith',
#   'Roger Wicker',
#   'Steve Daines',
#   'Jon Tester',
#   'Richard Burr',
#   'Thom Tillis',
#   'Kevin Cramer',
#   'John Hoeven',
#   'Deb Fischer',
#   'Ben Sasse',
#   'Margaret Hassan',
#   'Jeanne Shaheen',
#   'Cory Booker',
#   'Bob Menendez',
#   'Martin Heinrich',
#   'Ben Lujan',
#   'Catherine Cortez Masto',
#   'Jacky Rosen',
#   'Kirsten Gillibrand',
#   'Charles Schumer',
#   'Sherrod Brown',
#   'Rob Portman',
#   'James Inhofe',
#   'James Lankford',
#   'Jeff Merkley',
#   'Ron Wyden',
#   'Robert Casey',
#   'Patrick Toomey',
#   'Jack Reed',
#   'Sheldon Whitehouse',
#   'Lindsey Graham',
#   'Tim Scott',
#   'Mike Rounds',
#   'John Thune',
#   'Marsha Blackburn',
#   'Bill Hagerty',
#   'John Cornyn',
#   'Ted Cruz',
#   'Mike Lee',
#   'Mitt Romney',
#   'Tim Kaine',
#   'Mark Warner',
#   'Patrick Leahy',
#   'Bernard Sanders',
#   'Maria Cantwell',
#   'Patty Murrary',
#   'Tammy Baldwin',
#   'Ron Johnson',
#   'Shelley Capito',
#   'Joe Manchin',
#   'John Barrasso',
#   'Cynthia Lummis',
#   'Don Young',
#   'Robert Aderholt',
#   'Mo Brooks',
#   'Jerry Carl',
#   'Barry Moore',
#   'Gary Palmer',
#   'Mike Rogers',
#   'Terri Sewell',
#   'Rick Crawford',
#   'French Hill',
#   'Bruce Westerman',
#   'Steve Womack',
#   'Amata Radewagen',
#   'Andy Biggs',
#   'Ruben Gallego',
#   'Paul Gosar',
#   'Raul Grijalva',
#   'Ann Kirkpatrick',
#   'Debbie Lesko',
#   "Tom O'Halleran",
#   'David Schweikert',
#   'Greg Stanton',
#   'Pete Aguilar',
#   'Nanette Barragan',
#   'Karen Bass',
#   'Ami Bera',
#   'Julia Brownley',
#   'Ken Calvert',
#   'Salud Carbajal',
#   'Tony Cardenas',
#   'Judy Chu',
#   'J. Correa',
#   'Jim Costa',
#   'Mark DeSaulnier',
#   'Anna Eshoo',
#   'John Garamendi',
#   'Mike Garcia',
#   'Jimmy Gomez',
#   'Josh Harder',
#   'Jared Huffman',
#   'Darrell Issa',
#   'Sara Jacobs',
#   'Ro Khanna',
#   'Young Kim',
#   'Doug LaMalfa',
#   'Barbara Lee',
#   'Mike Levin',
#   'Ted Lieu',
#   'Zoe Lofgren',
#   'Alan Lowenthal',
#   'Doris Matsui',
#   'Kevin McCarthy',
#   'Tom McClintock',
#   'Jerry McNerney',
#   'Grace Napolitano',
#   'Devin Nunes',
#   'Jay Obernolte',
#   'Jimmy Panetta',
#   'Nancy Pelosi',
#   'Scott Peters',
#   'Katie Porter',
#   'Lucille Roybal-Allard',
#   'Raul Ruiz',
#   'Linda Sanchez',
#   'Adam Schiff',
#   'Brad Sherman',
#   'Jackie Speier',
#   'Michelle Steel',
#   'Eric Swalwell',
#   'Mark Takano',
#   'Mike Thompson',
#   'Norma Torres',
#   'David Valadao',
#   'Juan Vargas',
#   'Maxine Waters',
#   'Lauren Boebert',
#   'Ken Buck',
#   'Jason Crow',
#   'Diana DeGette',
#   'Doug Lamborn',
#   'Joe Neguse',
#   'Ed Perlmutter',
#   'Joe Courtney',
#   'Rosa DeLauro',
#   'Jahana Hayes',
#   'Jim Himes',
#   'John Larson',
#   'Eleanor Norton',
#   'Lisa Blunt Rochester',
#   'Gus Bilirakis',
#   'Vern Buchanan',
#   'Kat Cammack',
#   'Kathy Castor',
#   'Charlie Crist',
#   'Val Demings',
#   'Ted Deutch',
#   'Mario Diaz-Balart',
#   'Byron Donalds',
#   'Neal Dunn',
#   'Lois Frankel',
#   'C. Franklin',
#   'Matt Gaetz',
#   'Carlos Gimenez',
#   'Alcee Hastings',
#   'Al Lawson',
#   'Brian Mast',
#   'Stephanie Murphy',
#   'Bill Posey',
#   'John Rutherford',
#   'Maria Salazar',
#   'Darren Soto',
#   'W. Steube',
#   'Michael Waltz',
#   'Debbie Wasserman Schultz',
#   'Daniel Webster',
#   'Frederica Wilson',
#   'Rick Allen',
#   'Sanford Bishop Jr.',
#   'Carolyn Bourdeaux',
#   'Buddy Carter',
#   'Andrew Clyde',
#   'A. Ferguson',
#   'Majorie Greene',
#   'Jody Hice',
#   'Henry Johnson',
#   'Barry Loudermilk',
#   'Lucy McBath',
#   'Austin Scott',
#   'David Scott',
#   'Nikema Williams',
#   'Michael San Nicolas',
#   'Ed Case',
#   "Kaiali'i Kahele",
#   'Cindy Axne',
#   'Randy Feenstra',
#   'Ashley Hinson',
#   'Mariannette Miller-Meeks',
#   'Russ Fulcher',
#   'Mike Simpson',
#   'Mike Bost',
#   'Cheri Bustos',
#   'Sean Casten',
#   'Danny Davis',
#   'Rodney Davis',
#   'Bill Foster',
#   'Jesus Garcia',
#   'Robin Kelly',
#   'Adam Kinzinger',
#   'Raja Krishnamoorthi',
#   'Darin LaHood',
#   'Marie Newman',
#   'Mike Quigley',
#   'Bobby Rush',
#   'Jan Schakowsky',
#   'Bradley Schneider',
#   'Lauren Underwood',
#   'Jim Baird',
#   'Jim Banks',
#   'Larry Bucshon',
#   'Andr� Carson',
#   'Trey Hollingsworth',
#   'Frank Mrvan',
#   'Greg Pence',
#   'Victoria Spartz',
#   'Jackie Walorski',
#   'Sharice Davids',
#   'Ron Estes',
#   'Jake LaTurner',
#   'Tracey Mann',
#   'Andy Barr',
#   'James Comer',
#   'S. Guthrie',
#   'Thomas Massie',
#   'Harold Rogers',
#   'John Yarmuth',
#   'Garret Graves',
#   'Clay Higgins',
#   'Mike Johnson',
#   'Steve Scalise',
#   'Jake Auchincloss',
#   'Katherine Clark',
#   'William Keating',
#   'Stephen Lynch',
#   'James McGovern',
#   'Seth Moulton',
#   'Richard Neal',
#   'Ayanna Pressley',
#   'Lori Trahan',
#   'Anthony Brown',
#   'Andy Harris',
#   'Steny Hoyer',
#   'Kweisi Mfume',
#   'Jamie Raskin',
#   'C. Ruppersberger',
#   'John Sarbanes',
#   'David Trone',
#   'Jared Golden',
#   'Chellie Pingree',
#   'Jack Bergman',
#   'Debbie Dingell',
#   'Bill Huizenga',
#   'Dan Kildee',
#   'Brenda Lawrence',
#   'Andy Levin',
#   'Lisa McClain',
#   'Peter Meijer',
#   'John Moolenaar',
#   'Elissa Slotkin',
#   'Haley Stevens',
#   'Rashida Tlaib',
#   'Fred Upton',
#   'Tim Walberg',
#   'Angie Craig',
#   'Tom Emmer',
#   'Michelle Fischbach',
#   'Jim Hagedorn',
#   'Betty McCollum',
#   'Ilhan Omar',
#   'Dean Phillips',
#   'Pete Stauber',
#   'Cori Bush',
#   'Emanuel Cleaver',
#   'Sam Graves',
#   'Vicky Hartzler',
#   'Billy Long',
#   'Blaine Luetkemeyer',
#   'Jason Smith',
#   'Ann Wagner',
#   'Gregorio Sablan',
#   'Michael Guest',
#   'Trent Kelly',
#   'Steven Palazzo',
#   'Bernie Thompson',
#   'Matthew Rosendale',
#   'Alma Adams',
#   'Dan Bishop',
#   'Ted Budd',
#   'G.K. Butterfield',
#   'Madison Cawthorn',
#   'Virginia Foxx',
#   'Richard Hudson',
#   'Kathy Manning',
#   'Patrick McHenry',
#   'Gregory Murphy',
#   'David Price',
#   'Deborah Ross',
#   'David Rouzer',
#   'Kelly Armstrong',
#   'Don Bacon',
#   'Jeff Fortenberry',
#   'Adrian Smith',
#   'Ann Kuster',
#   'Chris Pappas',
#   'Josh Gottheimer',
#   'Andy Kim',
#   'Tom Malinowski',
#   'Donald Norcross',
#   'Frank Pallone Jr.',
#   'Bill Pascrell Jr.',
#   'Donald Payne Jr.',
#   'Mikie Sherrill',
#   'Albio Sires',
#   'Chris Smith',
#   'Jefferson Van Drew',
#   'Bonnie Watson Coleman',
#   'Debra Haaland',
#   'Yvette Herrell',
#   'Teresa Leger Fernandez',
#   'Mark Amodei',
#   'Steven Horsford',
#   'Susie Lee',
#   'Dina Titus',
#   'Jamaal Bowman',
#   'Yvette Clarke',
#   'Antonio Delgado',
#   'Adriano Espaillat',
#   'Andrew Garbarino',
#   'Brian Higgins',
#   'Chris Jacobs',
#   'Hakeem Jeffries',
#   'Mondaire Jones',
#   'John Katko',
#   'Nicole Malliotakis',
#   'Carolyn Maloney',
#   'Sean Maloney',
#   'Gregory Meeks',
#   'Grace Meng',
#   'Jospeh Morelle',
#   'Jerrold Nadler',
#   'Alexandria Ocasio-Cortez',
#   'Tom Reed',
#   'Kathleen Rice',
#   'Elise Stefanik',
#   'Thomas Suozzi',
#   'Paul Tonko',
#   'Ritchie Torres',
#   'Nydia Velazquez',
#   'Lee Zeldin',
#   'Troy Balderson',
#   'Joyce Beatty',
#   'Steve Chabot',
#   'Warren Davidson',
#   'Marcia Fudge',
#   'Bob Gibbs',
#   'Anthony Gonzalez',
#   'Bill Johnson',
#   'Jim Jordan',
#   'David Joyce',
#   'Marcy Kaptur',
#   'Robert Latta',
#   'Tim Ryan',
#   'Steve Stivers',
#   'Mike Turner',
#   'Brad Wenstrup',
#   'Stephanie Bice',
#   'Tom Cole',
#   'Kevin Hern',
#   'Frank Lucas',
#   'Markwayne Mullin',
#   'Cliff Bentz',
#   'Earl Blumenauer',
#   'Suzanne Bonamici',
#   'Peter DeFazio',
#   'Kurt Schrader',
#   'Brendan Boyle',
#   'Matt Cartwright',
#   'Madeleine Dean',
#   'Michael Doyle',
#   'Dwight Evans',
#   'Brian Fitzpatrick',
#   'Chrissy Houlahan',
#   'John Joyce',
#   'Fred Keller',
#   'Mike Kelly',
#   'Conor Lamb',
#   'Daniel Meuser',
#   'Scott Perry',
#   'Guy Reschenthaler',
#   'Mary Scanlon',
#   'Lloyd Smucker',
#   'Glenn Thompson',
#   'Susan Wild',
#   'Jenniffer Gonzalez-Colon',
#   'David Cicilline',
#   'Jim Langevin',
#   'James Clyburn',
#   'Jeff Duncan',
#   'Nancy Mace',
#   'Ralph Norman',
#   'Tom Rice',
#   'William Timmons',
#   'Joe Wilson',
#   'Dusty Johnson',
#   'Tim Burchett',
#   'Steve Cohen',
#   'Jim Cooper',
#   'Scott DesJarlais',
#   'Chuck Fleischmann',
#   'Mark Green',
#   'Diana Harshbarger',
#   'David Kustoff',
#   'John Rose',
#   'Colin Allred',
#   'Jodey Arrington',
#   'Brian Babin',
#   'Kevin Brady',
#   'Michael Burgess',
#   'John Carter',
#   'Joaquin Castro',
#   'Michael Cloud',
#   'Dan Crenshaw',
#   'Henry Cuellar',
#   'Lloyd Doggett',
#   'Veronica Escobar',
#   'Pat Fallon',
#   'Lizzie Fletcher',
#   'Sylvia Garcia',
#   'Louie Gohmert',
#   'Tony Gonzales',
#   'Vicente Gonzalez',
#   'Lance Gooden',
#   'Kay Granger',
#   'Al Green',
#   'Sheila Jackson Lee',
#   'Ronny Jackson',
#   'Eddie Johnson',
#   'Michael McCaul',
#   'Troy Nehls',
#   'August Pfluger',
#   'Chip Roy',
#   'Pete Sessions',
#   'Van Taylor',
#   'Beth Van Duyne',
#   'Marc Veasey',
#   'Filemon Vela',
#   'Randy Weber',
#   'Roger Williams',
#   'Ron Wright',
#   'John Curtis',
#   'Blake Moore',
#   'Burgess Owens',
#   'Chris Stewart',
#   'Don Beyer',
#   'Ben Cline',
#   'Gerald Connolly',
#   'Bob Good',
#   'Morgan Griffith',
#   'Elaine Luria',
#   'A. McEachin',
#   'Robert Scott',
#   'Abigail Spanberger',
#   'Jennifer Wexton',
#   'Robert Wittman',
#   'Stacey Plaskett',
#   'Peter Welch',
#   'Suzan DelBene',
#   'Jaime Herrera Butler',
#   'Pramila Jayapal',
#   'Derek Kilmer',
#   'Rick Larsen',
#   'Dan Newhouse',
#   'Cathy Rodgers',
#   'Kim Schrier',
#   'Adam Smith',
#   'Marilyn Strickland',
#   'Scott Fitzgerald',
#   'Mike Gallagher',
#   'Glenn Grothman',
#   'Ron Kind',
#   'Gwen Moore',
#   'Mark Pocan',
#   'Bryan Steil',
#   'Thomas Tiffany',
#   'David McKinley',
#   'Carol Miller',
#   'Mary Miller',
#   'Alex Mooney',
#   'Liz Cheney'],
#  'username': ['lisamurkowski',
#   'SenDanSullivan',
#   'SenShelby',
#   'SenTuberville',
#   'JohnBoozman',
#   'SenTomCotton',
#   'SenMarkKelly',
#   'SenatorSinema',
#   'SenFeinstein',
#   'SenAlexPadilla',
#   'SenatorBennet',
#   'SenatorHick',
#   'SenBlumenthal',
#   'ChrisMurphyCT',
#   'SenatorCarper',
#   'ChrisCoons',
#   'marcorubio',
#   'SenRickScott',
#   'ossoff',
#   'SenatorWarnock',
#   'maziehirono',
#   'SenBrianSchatz',
#   'SenJoniErnst',
#   'ChuckGrassley',
#   'MikeCrapo',
#   'SenatorRisch',
#   'SenDuckworth',
#   'SenatorDurbin',
#   'SenatorBraun',
#   'SenToddYoung',
#   'SenatorMarshall',
#   'JerryMoran',
#   'senatemajldr',
#   'RandPaul',
#   'SenBillCassidy',
#   'SenJohnKennedy',
#   'SenMarkey',
#   'SenWarren',
#   'SenatorCardin',
#   'ChrisVanHollen',
#   'SenatorCollins',
#   'Jr.',
#   'SenGaryPeters',
#   'SenStabenow',
#   'SenAmyKlobuchar',
#   'SenTinaSmith',
#   'RoyBlunt',
#   'HawleyMO',
#   'SenHydeSmith',
#   'SenatorWicker',
#   'SteveDaines',
#   'SenatorTester',
#   'SenatorBurr',
#   'SenThomTillis',
#   'SenKevinCramer',
#   'SenJohnHoeven',
#   'SenatorFischer',
#   'SenSasse',
#   'SenatorHassan',
#   'SenatorShaheen',
#   'CoryBooker',
#   'SenatorMenendez',
#   'MartinHeinrich',
#   'SenatorLujan',
#   'SenCortezMasto',
#   'SenJackyRosen',
#   'SenGillibrand',
#   'SenSchumer',
#   'SenSherrodBrown',
#   'senrobportman',
#   'JimInhofe',
#   'SenatorLankford',
#   'SenJeffMerkley',
#   'RonWyden',
#   'Jr.',
#   'SenToomey',
#   'SenJackReed',
#   'SenWhitehouse',
#   'LindseyGrahamSC',
#   'SenatorTimScott',
#   'SenatorRounds',
#   'SenJohnThune',
#   'MarshaBlackburn',
#   'SenatorHagerty',
#   'JohnCornyn',
#   'SenTedCruz',
#   'SenMikeLee',
#   'SenatorRomney',
#   'timkaine',
#   'MarkWarner',
#   'SenatorLeahy',
#   'SenSanders',
#   'SenatorCantwell',
#   'PattyMurray',
#   'SenatorBaldwin',
#   'SenRonJohnson',
#   'SenCapito',
#   nan,
#   'SenJohnBarrasso',
#   'SenLummis',
#   'repdonyoung',
#   'Robert_Aderholt',
#   'RepMoBrooks',
#   'RepJerryCarl',
#   'RepBarryMoore',
#   'USRepGaryPalmer',
#   'RepMikeRogersAL',
#   'RepTerriSewell',
#   'RepRickCrawford',
#   'RepFrenchHill',
#   'RepWesterman',
#   'rep_stevewomack',
#   'RepAmata',
#   'RepAndyBiggsAZ',
#   'RepRubenGallego',
#   'RepGosar',
#   'RepRaulGrijalva',
#   'RepKirkpatrick',
#   'RepDLesko',
#   'RepOHalleran',
#   'RepDavid',
#   'RepGregStanton',
#   'RepPeteAguilar',
#   'RepBarragan',
#   'RepKarenBass',
#   'RepBera',
#   'RepBrownley',
#   'KenCalvert',
#   'RepCarbajal',
#   'RepCardenas',
#   'RepJudyChu',
#   'RepLouCorrea',
#   'RepJimCosta',
#   'RepDeSaulnier',
#   'RepAnnaEshoo',
#   'RepGaramendi',
#   'RepMikeGarcia',
#   'RepJimmyGomez',
#   'RepJoshHarder',
#   'RepHuffman',
#   'repdarrellissa',
#   'RepSaraJacobs',
#   'RepRoKhanna',
#   'RepYoungKim',
#   'RepLaMalfa',
#   'RepBarbaraLee',
#   'RepMikeLevin',
#   'RepTedLieu',
#   'RepZoeLofgren',
#   'RepLowenthal',
#   'DorisMatsui',
#   'GOPLeader',
#   'RepMcClintock',
#   'RepMcNerney',
#   'gracenapolitano',
#   'RepDevinNunes',
#   'JayObernolte',
#   'RepJimmyPanetta',
#   'SpeakerPelosi',
#   'RepScottPeters',
#   'RepKatiePorter',
#   'RepRoybalAllard',
#   'RepRaulRuizMD',
#   'RepLindaSanchez',
#   'RepAdamSchiff',
#   'BradSherman',
#   'RepSpeier',
#   'RepSteel',
#   'RepSwalwell',
#   'RepMarkTakano',
#   'RepThompson',
#   'NormaJTorres',
#   'RepDavidValadao',
#   'RepJuanVargas',
#   'RepMaxineWaters',
#   'RepBoebert',
#   'RepKenBuck',
#   'RepJasonCrow',
#   'RepDianaDeGette',
#   'RepDLamborn',
#   'RepJoeNeguse',
#   'RepPerlmutter',
#   'RepJoeCourtney',
#   'rosadelauro',
#   'RepJahanaHayes',
#   'jahimes',
#   'RepJohnLarson',
#   'EleanorNorton',
#   'RepLBR',
#   'RepGusBilirakis',
#   'VernBuchanan',
#   'RepKatCammack',
#   'USRepKCastor',
#   'RepCharlieCrist',
#   'RepValDemings',
#   'RepTedDeutch',
#   'MarioDB',
#   'RepDonaldsPress',
#   'DrNealDunnFL2',
#   'RepLoisFrankel',
#   'RepFranklin',
#   'RepMattGaetz',
#   'RepCarlos',
#   'RepHastingsFL',
#   'RepAlLawsonJr',
#   'RepBrianMast',
#   'RepStephMurphy',
#   'congbillposey',
#   'RepRutherfordFL',
#   'RepMariaSalazar',
#   'RepDarrenSoto',
#   'RepGregSteube',
#   'michaelgwaltz',
#   'RepDWStweets',
#   'RepWebster',
#   'RepWilson',
#   'RepRickAllen',
#   'SanfordBishop',
#   'RepBourdeaux',
#   'RepBuddyCarter',
#   'GA',
#   'RepDrewFerguson',
#   'RepMTG',
#   'CongressmanHice',
#   'Hank',
#   'RepLoudermilk',
#   'RepLucyMcBath',
#   'AustinScottGA08',
#   'repdavidscott',
#   'RepNikema',
#   'GuamCongressman',
#   'RepEdCase',
#   'KaheleRep',
#   'RepCindyAxne',
#   'RepFeenstra',
#   'RepAshleyHinson',
#   'RepMMM',
#   'RepRussFulcher',
#   'CongMikeSimpson',
#   'RepBost',
#   'RepCheri',
#   'RepCasten',
#   'RepDannyDavis',
#   'RodneyDavis',
#   'RepBillFoster',
#   'RepChuyGarcia',
#   'RepRobinKelly',
#   'RepKinzinger',
#   'CongressmanRaja',
#   'RepLaHood',
#   'RepMarieNewman',
#   'RepMikeQuigley',
#   'RepBobbyRush',
#   'janschakowsky',
#   'RepSchneider',
#   'RepUnderwood',
#   'RepJimBaird',
#   'RepJimBanks',
#   'RepLarryBucshon',
#   'RepAndreCarson',
#   'RepTrey',
#   'RepMrvan',
#   'RepGregPence',
#   'RepSpartz',
#   'RepWalorski',
#   'RepDavids',
#   'RepRonEstes',
#   'RepLaTurner',
#   'RepMann',
#   'RepAndyBarr',
#   'RepJamesComer',
#   'RepGuthrie',
#   'RepThomasMassie',
#   'RepHalRogers',
#   'RepJohnYarmuth',
#   'RepGarretGraves',
#   'RepClayHiggins',
#   'RepMikeJohnson',
#   'SteveScalise',
#   'RepAuchincloss',
#   'RepKClark',
#   'USRepKeating',
#   'RepStephenLynch',
#   'RepMcGovern',
#   'teammoulton',
#   'RepRichardNeal',
#   'RepPressley',
#   'RepLoriTrahan',
#   'RepAnthonyBrown',
#   'RepAndyHarrisMD',
#   'LeaderHoyer',
#   'RepKweisiMfume',
#   'RepRaskin',
#   'Dutch',
#   'RepSarbanes',
#   'RepDavidTrone',
#   'RepGolden',
#   'chelliepingree',
#   'RepJackBergman',
#   'RepDebDingell',
#   'RepHuizenga',
#   'RepDanKildee',
#   'RepLawrence',
#   'RepAndyLevin',
#   'RepLisaMcClain',
#   'RepMeijer',
#   'RepMoolenaar',
#   'RepSlotkin',
#   'RepHaleyStevens',
#   'RepRashida',
#   'RepFredUpton',
#   'RepWalberg',
#   'RepAngieCraig',
#   'RepTomEmmer',
#   'RepFischbach',
#   'RepHagedorn',
#   'BettyMcCollum04',
#   'Ilhan',
#   'RepDeanPhillips',
#   'RepPeteStauber',
#   'RepCori',
#   'repcleaver',
#   'RepSamGraves',
#   'RepHartzler',
#   'USRepLong',
#   'RepBlaine',
#   'RepJasonSmith',
#   'RepAnnWagner',
#   'Kilili_Sablan',
#   'RepMichaelGuest',
#   'RepTrentKelly',
#   'CongPalazzo',
#   'BennieGThompson',
#   'RepRosendale',
#   'RepAdams',
#   'RepDanBishop',
#   'RepTedBudd',
#   'GKButterfield',
#   'RepCawthorn',
#   'virginiafoxx',
#   'RepRichHudson',
#   'RepKManning',
#   'PatrickMcHenry',
#   'RepGregMurphy',
#   'RepDavidEPrice',
#   'RepDeborahRoss',
#   'RepDavidRouzer',
#   'RepArmstrongND',
#   'RepDonBacon',
#   'JeffFortenberry',
#   'RepAdrianSmith',
#   'RepAnnieKuster',
#   'RepChrisPappas',
#   'RepJoshG',
#   'RepAndyKimNJ',
#   'RepMalinowski',
#   'DonaldNorcross',
#   'FrankPallone',
#   'BillPascrell',
#   'RepDonaldPayne',
#   'RepSherrill',
#   'RepSires',
#   'R',
#   'R',
#   'RepBonnie',
#   'RepDebHaaland',
#   'RepHerrell',
#   'RepTeresaLF',
#   'MarkAmodeiNV2',
#   'RepHorsford',
#   'RepSusieLee',
#   'repdinatitus',
#   'RepBowman',
#   'RepYvetteClarke',
#   'repdelgado',
#   'RepEspaillat',
#   'RepGarbarino',
#   'RepBrianHiggins',
#   'RepJacobs',
#   'RepJeffries',
#   'RepMondaire',
#   'RepJohnKatko',
#   'RepMalliotakis',
#   'RepMaloney',
#   'RepSeanMaloney',
#   'RepGregoryMeeks',
#   'RepGraceMeng',
#   'RepJoeMorelle',
#   'RepJerryNadler',
#   'RepAOC',
#   'RepTomReed',
#   'RepKathleenRice',
#   'RepStefanik',
#   'RepTomSuozzi',
#   'RepPaulTonko',
#   'RepRitchie',
#   'NydiaVelazquez',
#   'RepLeeZeldin',
#   'RepBalderson',
#   'RepBeatty',
#   'RepSteveChabot',
#   'WarrenDavidson',
#   'RepMarciaFudge',
#   'RepBobGibbs',
#   'RepAGonzalez',
#   'RepBillJohnson',
#   'Jim_Jordan',
#   'RepDaveJoyce',
#   'RepMarcyKaptur',
#   'boblatta',
#   'RepTimRyan',
#   'RepSteveStivers',
#   'RepMikeTurner',
#   'RepBradWenstrup',
#   'RepBice',
#   'TomColeOK04',
#   'repkevinhern',
#   'RepFrankLucas',
#   'RepMullin',
#   'RepBentz',
#   'repblumenauer',
#   'RepBonamici',
#   'RepPeterDeFazio',
#   'RepSchrader',
#   'CongBoyle',
#   'RepCartwright',
#   'RepDean',
#   'USRepMikeDoyle',
#   'RepDwightEvans',
#   'RepBrianFitz',
#   'RepHoulahan',
#   'RepJohnJoyce',
#   'RepFredKeller',
#   'MikeKellyPA',
#   'RepConorLamb',
#   'RepMeuser',
#   'RepScottPerry',
#   'GReschenthaler',
#   'RepMGS',
#   'RepSmucker',
#   'CongressmanGT',
#   'RepSusanWild',
#   'RepJenniffer',
#   'RepCicilline',
#   'JimLangevin',
#   'WhipClyburn',
#   'RepJeffDuncan',
#   'RepNancyMace',
#   'RepRalphNorman',
#   'RepTomRice',
#   'RepTimmons',
#   'RepJoeWilson',
#   'RepDustyJohnson',
#   'RepTimBurchett',
#   'RepCohen',
#   'repjimcooper',
#   'DesJarlaisTN04',
#   'RepChuck',
#   'RepMarkGreen',
#   'RepHarshbarger',
#   'RepDavidKustoff',
#   'RepJohnRose',
#   'RepColinAllred',
#   'RepArrington',
#   'RepBrianBabin',
#   'RepKevinBrady',
#   'michaelcburgess',
#   'JudgeCarter',
#   'JoaquinCastrotx',
#   'RepCloudTX',
#   'RepDanCrenshaw',
#   'RepCuellar',
#   'RepLloydDoggett',
#   'RepEscobar',
#   'RepPatFallon',
#   'RepFletcher',
#   'RepSylviaGarcia',
#   'replouiegohmert',
#   'RepTonyGonzales',
#   'RepGonzalez',
#   'R',
#   'RepKayGranger',
#   'RepAlGreen',
#   'JacksonLeeTX18',
#   'RepRonnyJackson',
#   'RepEBJ',
#   'RepMcCaul',
#   'RepTroyNehls',
#   'RepPfluger',
#   'RepChipRoy',
#   'PeteSessions',
#   'RepVanTaylor',
#   'RepBethVanDuyne',
#   'RepVeasey',
#   'RepFilemonVela',
#   'TXRandy14',
#   'RepRWilliams',
#   'RepRonWright',
#   'RepJohnCurtis',
#   'RepBlakeMoore',
#   'RepBurgessOwens',
#   'RepChrisStewart',
#   'RepDonBeyer',
#   'RepBenCline',
#   'Gerry',
#   'RepBobGood',
#   'RepMGriffith',
#   'RepElaineLuria',
#   'RepMcEachin',
#   'BobbyScott',
#   'RepSpanberger',
#   'RepWexton',
#   'RobWittman',
#   'StaceyPlaskett',
#   'PeterWelch',
#   'RepDelBene',
#   'HerreraBeutler',
#   'RepJayapal',
#   'RepDerekKilmer',
#   'RepRickLarsen',
#   'RepNewhouse',
#   'cathymcmorris',
#   'RepKimSchrier',
#   'RepAdamSmith',
#   'RepStricklandWA',
#   'RepFitzgerald',
#   'RepGallagher',
#   'RepGrothman',
#   'RepRonKind',
#   'RepGwenMoore',
#   'repmarkpocan',
#   'RepBryanSteil',
#   'RepTiffany',
#   'RepMcKinley',
#   'RepCarolMiller',
#   'RepMaryMiller',
#   'RepAlexMooney',
#   'RepLizCheney']}

# %%
names_handles = pd.DataFrame(data = {"name":full_names, "username":actual_handles})

# %%
names_handles.to_csv("data/member_handles.csv", index = False)

# %% [markdown]
# ### Merging DFs

# %%
pd.set_option("display.max_rows", None)

# %%
with open("data/caucus_117.json", "r") as file:
    caucuses = json.load(file)

progressive = caucuses["Progressive Caucus"]
new_democratic = caucuses["New Democratic Coalition"]
problem_solvers = caucuses["Problem Solvers Caucus"]
rep_gov_group = caucuses["Republican Governance Group"]
rep_study_com = caucuses["Republican Study Committee"]
freedom = caucuses["Freedom Caucus"]

# %%
members = pd.read_csv("data/member_handles.csv")
members.head(5)
# Out:
#                name        username
# 0    Lisa Murkowski   lisamurkowski
# 1      Dan Sullivan  SenDanSullivan
# 2    Richard Shelby       SenShelby
# 3  Tommy Tuberville   SenTuberville
# 4      John Boozman     JohnBoozman

# %%
prog_df = pd.DataFrame(data = {"name":progressive, "progressive caucus":[True]*len(progressive)})
new_dem_df = pd.DataFrame(data = {"name":new_democratic, "new democratic coalition":[True]*len(new_democratic)})
prob_solvers_df = pd.DataFrame(data = {"name":problem_solvers, "problem solvers caucus":[True]*len(problem_solvers)})
rep_gov_df = pd.DataFrame(data = {"name":rep_gov_group, "republican governance group":[True]*len(rep_gov_group)})
rep_study_df = pd.DataFrame(data = {"name":rep_study_com, "republican study committee":[True]*len(rep_study_com)})
freedom_df = pd.DataFrame(data = {"name":freedom, "freedom caucus":[True]*len(freedom)})

# %%
num_members = f'''
# of Members per Caucus

Progressive Caucus: {len(prog_df)}
New Democratic Coalition: {len(new_dem_df)}
Problem Solvers Caucus: {len(prob_solvers_df)}
Republican Governance Group: {len(rep_gov_df)}
Republican Study Committee: {len(rep_study_df)}
Freedom Caucus: {len(freedom_df)}
'''

# %%
print(num_members)
# Out:
# # of Members per Caucus
#
# Progressive Caucus: 92
# New Democratic Coalition: 98
# Problem Solvers Caucus: 52
# Republican Governance Group: 45
# Republican Study Committee: 159
# Freedom Caucus: 39

# %%
members = pd.merge(members, prog_df, how = "left", on = "name")
members = pd.merge(members, new_dem_df, how = "left", on = "name")
members = pd.merge(members, prob_solvers_df, how = "left", on = "name")
members = pd.merge(members, rep_gov_df, how = "left", on = "name")
members = pd.merge(members, rep_study_df, how = "left", on = "name")
members = pd.merge(members, freedom_df, how = "outer", on = "name")

# %%
len(freedom_df)
# Out:
# 39

# %%
sum(members["freedom caucus"] == True)
# Out:
# 39

# %%
members.to_csv("data/members_caucuses.csv", index = False)

# %%
members
# Out:
#                          name         username progressive caucus  \
# 0          Abigail Spanberger    RepSpanberger                NaN
# 1              Adam Kinzinger     RepKinzinger                NaN
# 2                 Adam Schiff    RepAdamSchiff                NaN
# 3                  Adam Smith     RepAdamSmith               True
# 4                Adrian Smith   RepAdrianSmith                NaN
# 5           Adriano Espaillat     RepEspaillat               True
# 6                    Al Green       RepAlGreen                NaN
# 7                   Al Lawson    RepAlLawsonJr                NaN
# 8              Alan Lowenthal     RepLowenthal               True
# 9                 Albio Sires         RepSires                NaN
# 10             Alcee Hastings    RepHastingsFL                NaN
# 11                Alex Mooney    RepAlexMooney                NaN
# 12               Alex Padilla   SenAlexPadilla                NaN
# 13   Alexandria Ocasio-Cortez           RepAOC               True
# 14                 Alma Adams         RepAdams               True
# 15            Amata Radewagen         RepAmata                NaN
# 16                   Ami Bera          RepBera                NaN
# 17              Amy Klobuchar  SenAmyKlobuchar                NaN
# 18               Andre Carson   RepAndreCarson               True
# 19               Andrew Clyde        Rep_Clyde                NaN
# 20           Andrew Garbarino     RepGarbarino                NaN
# 21                  Andy Barr      RepAndyBarr                NaN
# 22                 Andy Biggs   RepAndyBiggsAZ                NaN
# 23                Andy Harris  RepAndyHarrisMD                NaN
# 24                   Andy Kim     RepAndyKimNJ               True
# 25                 Andy Levin     RepAndyLevin               True
# 26                Angie Craig    RepAngieCraig                NaN
# 27                 Angus King     SenAngusKing                NaN
# 28            Ann Kirkpatrick   RepKirkpatrick                NaN
# 29          Ann McLane Kuster   RepAnnieKuster                NaN
# 30                 Ann Wagner     RepAnnWagner                NaN
# 31                 Anna Eshoo     RepAnnaEshoo                NaN
# 32              Anthony Brown  RepAnthonyBrown                NaN
# 33           Anthony Gonzalez     RepAGonzalez                NaN
# 34            Antonio Delgado       repdelgado                NaN
# 35              Ashley Hinson  RepAshleyHinson                NaN
# 36             August Pfluger       RepPfluger                NaN
# 37               Austin Scott  AustinScottGA08                NaN
# 38            Ayanna Pressley      RepPressley               True
# 39                Barbara Lee    RepBarbaraLee               True
# 40           Barry Loudermilk    RepLoudermilk                NaN
# 41                Barry Moore    RepBarryMoore                NaN
# 42                  Ben Cline      RepBenCline                NaN
# 43                  Ben Lujan     SenatorLujan                NaN
# 44                  Ben Sasse         SenSasse                NaN
# 45            Benjamin Cardin    SenatorCardin                NaN
# 46             Bernie Sanders       SenSanders               True
# 47            Bernie Thompson  BennieGThompson                NaN
# 48             Beth Van Duyne  RepBethVanDuyne                NaN
# 49             Betty McCollum  BettyMcCollum04                NaN
# 50               Bill Cassidy   SenBillCassidy                NaN
# 51                Bill Foster    RepBillFoster                NaN
# 52               Bill Hagerty   SenatorHagerty                NaN
# 53              Bill Huizenga      RepHuizenga                NaN
# 54               Bill Johnson   RepBillJohnson                NaN
# 55               Bill Keating     USRepKeating                NaN
# 56              Bill Pascrell     BillPascrell                NaN
# 57                 Bill Posey    congbillposey                NaN
# 58                 Billy Long        USRepLong                NaN
# 59         Blaine Luetkemeyer        RepBlaine                NaN
# 60                Blake Moore    RepBlakeMoore                NaN
# 61                  Bob Gibbs      RepBobGibbs                NaN
# 62                   Bob Good       RepBobGood                NaN
# 63               Bob Menendez  SenatorMenendez                NaN
# 64                 Bobby Rush     RepBobbyRush                NaN
# 65      Bonnie Watson Coleman        RepBonnie               True
# 66             Brad Schneider     RepSchneider                NaN
# 67               Brad Sherman      BradSherman               True
# 68              Brad Wenstrup  RepBradWenstrup                NaN
# 69            Brenda Lawrence      RepLawrence               True
# 70              Brendan Boyle        CongBoyle               True
# 71              Brett Guthrie       RepGuthrie                NaN
# 72                Brian Babin    RepBrianBabin                NaN
# 73          Brian Fitzpatrick     RepBrianFitz                NaN
# 74              Brian Higgins  RepBrianHiggins                NaN
# 75                 Brian Mast     RepBrianMast                NaN
# 76               Brian Schatz   SenBrianSchatz                NaN
# 77            Bruce Westerman     RepWesterman                NaN
# 78                Bryan Steil    RepBryanSteil                NaN
# 79               Buddy Carter   RepBuddyCarter                NaN
# 80              Burgess Owens  RepBurgessOwens                NaN
# 81              Byron Donalds  RepDonaldsPress                NaN
# 82             Carlos Gimenez        RepCarlos                NaN
# 83               Carol Miller   RepCarolMiller                NaN
# 84          Carolyn Bourdeaux     RepBourdeaux                NaN
# 85            Carolyn Maloney       RepMaloney               True
# 86     Catherine Cortez Masto   SenCortezMasto                NaN
# 87     Cathy McMorris Rodgers    cathymcmorris                NaN
# 88            Charles Schumer       SenSchumer                NaN
# 89              Charlie Crist  RepCharlieCrist                NaN
# 90            Chellie Pingree   chelliepingree               True
# 91               Cheri Bustos         RepCheri                NaN
# 92                   Chip Roy       RepChipRoy                NaN
# 93               Chris Jacobs        RepJacobs                NaN
# 94               Chris Pappas   RepChrisPappas                NaN
# 95                Chris Smith              NaN                NaN
# 96              Chris Stewart  RepChrisStewart                NaN
# 97           Chris Van Hollen   ChrisVanHollen                NaN
# 98           Chrissy Houlahan      RepHoulahan                NaN
# 99           Chrissy Houlahan      RepHoulahan                NaN
# 100         Christopher Coons       ChrisCoons                NaN
# 101        Christopher Murphy    ChrisMurphyCT                NaN
# 102         Chuck Fleischmann         RepChuck                NaN
# 103            Chuck Grassley    ChuckGrassley                NaN
# 104                Cindy Axne     RepCindyAxne                NaN
# 105          Cindy Hyde-Smith     SenHydeSmith                NaN
# 106            Claudia Tenney        RepTenney                NaN
# 107              Clay Higgins   RepClayHiggins                NaN
# 108               Cliff Bentz         RepBentz                NaN
# 109              Colin Allred   RepColinAllred                NaN
# 110                Conor Lamb     RepConorLamb                NaN
# 111                 Cori Bush          RepCori               True
# 112               Cory Booker       CoryBooker                NaN
# 113            Cynthia Lummis        SenLummis                NaN
# 114                Dan Bishop     RepDanBishop                NaN
# 115              Dan Crenshaw   RepDanCrenshaw                NaN
# 116                Dan Kildee     RepDanKildee               True
# 117              Dan Newhouse      RepNewhouse                NaN
# 118              Dan Sullivan   SenDanSullivan                NaN
# 119             Daniel Meuser        RepMeuser                NaN
# 120            Daniel Webster       RepWebster                NaN
# 121               Danny Davis    RepDannyDavis                NaN
# 122              Darin LaHood        RepLaHood                NaN
# 123              Darrell Issa   repdarrellissa                NaN
# 124               Darren Soto    RepDarrenSoto               True
# 125           David Cicilline     RepCicilline               True
# 126               David Joyce     RepDaveJoyce                NaN
# 127             David Kustoff  RepDavidKustoff                NaN
# 128            David McKinley      RepMcKinley                NaN
# 129               David Price   RepDavidEPrice                NaN
# 130              David Rouzer   RepDavidRouzer                NaN
# 131          David Schweikert         RepDavid                NaN
# 132               David Scott    repdavidscott                NaN
# 133               David Trone    RepDavidTrone                NaN
# 134             David Valadao  RepDavidValadao                NaN
# 135             Dean Phillips  RepDeanPhillips                NaN
# 136               Deb Fischer   SenatorFischer                NaN
# 137            Debbie Dingell    RepDebDingell               True
# 138              Debbie Lesko        RepDLesko                NaN
# 139           Debbie Stabenow      SenStabenow                NaN
# 140  Debbie Wasserman Schultz     RepDWStweets                NaN
# 141              Deborah Ross   RepDeborahRoss                NaN
# 142             Debra Haaland    RepDebHaaland                NaN
# 143              Derek Kilmer   RepDerekKilmer                NaN
# 144               Devin Nunes    RepDevinNunes                NaN
# 145             Diana DeGette  RepDianaDeGette               True
# 146         Diana Harshbarger   RepHarshbarger                NaN
# 147          Dianne Feinstein     SenFeinstein                NaN
# 148                Dina Titus     repdinatitus                NaN
# 149                 Don Bacon      RepDonBacon                NaN
# 150                 Don Beyer      RepDonBeyer               True
# 151                 Don Young      repdonyoung                NaN
# 152           Donald McEachin      RepMcEachin                NaN
# 153           Donald Norcross   DonaldNorcross               True
# 154              Donald Payne   RepDonaldPayne                NaN
# 155              Doris Matsui      DorisMatsui                NaN
# 156              Doug LaMalfa       RepLaMalfa                NaN
# 157              Doug Lamborn      RepDLamborn                NaN
# 158             Drew Ferguson  RepDrewFerguson                NaN
# 159             Dusty Johnson  RepDustyJohnson                NaN
# 160       Dutch Ruppersberger    Call_Me_Dutch                NaN
# 161              Dwight Evans   RepDwightEvans               True
# 162           Earl Blumenauer    repblumenauer               True
# 163                   Ed Case        RepEdCase                NaN
# 164             Ed Perlmutter    RepPerlmutter                NaN
# 165     Eddie Bernice Johnson           RepEBJ               True
# 166             Edward Markey        SenMarkey                NaN
# 167              Elaine Luria   RepElaineLuria                NaN
# 168     Eleanor Holmes Norton    EleanorNorton               True
# 169            Elise Stefanik      RepStefanik                NaN
# 170            Elissa Slotkin       RepSlotkin                NaN
# 171          Elizabeth Warren        SenWarren                NaN
# 172           Emanuel Cleaver       repcleaver                NaN
# 173             Eric Swalwell      RepSwalwell                NaN
# 174              Filemon Vela   RepFilemonVela                NaN
# 175               Frank Lucas    RepFrankLucas                NaN
# 176               Frank Mrvan         RepMrvan                NaN
# 177             Frank Pallone     FrankPallone               True
# 178               Fred Keller    RepFredKeller                NaN
# 179                Fred Upton     RepFredUpton                NaN
# 180          Frederica Wilson        RepWilson               True
# 181               French Hill    RepFrenchHill                NaN
# 182          G.K. Butterfield    GKButterfield                NaN
# 183             Garret Graves  RepGarretGraves                NaN
# 184               Gary Palmer  USRepGaryPalmer                NaN
# 185               Gary Peters    SenGaryPeters                NaN
# 186            Gerry Connolly    GerryConnolly                NaN
# 187            Glenn Grothman      RepGrothman                NaN
# 188            Glenn Thompson    CongressmanGT                NaN
# 189                Grace Meng     RepGraceMeng               True
# 190          Grace Napolitano  gracenapolitano               True
# 191                Greg Pence     RepGregPence                NaN
# 192              Greg Stanton   RepGregStanton                NaN
# 193               Greg Steube    RepGregSteube                NaN
# 194           Gregorio Sablan    Kilili_Sablan                NaN
# 195             Gregory Meeks  RepGregoryMeeks                NaN
# 196            Gregory Murphy    RepGregMurphy                NaN
# 197             Gus Bilirakis  RepGusBilirakis                NaN
# 198         Guy Reschenthaler   GReschenthaler                NaN
# 199                Gwen Moore     RepGwenMoore               True
# 200           Hakeem Jeffries      RepJeffries               True
# 201             Haley Stevens  RepHaleyStevens                NaN
# 202             Harold Rogers     RepHalRogers                NaN
# 203             Henry Cuellar       RepCuellar                NaN
# 204             Henry Johnson   RepHankJohnson                NaN
# 205                Ilhan Omar            Ilhan               True
# 206              Jack Bergman   RepJackBergman                NaN
# 207                 Jack Reed      SenJackReed                NaN
# 208             Jackie Speier        RepSpeier                NaN
# 209           Jackie Walorski      RepWalorski                NaN
# 210               Jacky Rosen    SenJackyRosen                NaN
# 211              Jahana Hayes   RepJahanaHayes                NaN
# 212     Jaime Herrera Beutler   HerreraBeutler                NaN
# 213          Jake Auchincloss   RepAuchincloss                NaN
# 214             Jake LaTurner      RepLaTurner                NaN
# 215             Jamaal Bowman        RepBowman               True
# 216             James Clyburn      WhipClyburn                NaN
# 217               James Comer    RepJamesComer                NaN
# 218              James Inhofe        JimInhofe                NaN
# 219            James Lankford  SenatorLankford                NaN
# 220            James McGovern      RepMcGovern               True
# 221               James Risch     SenatorRisch                NaN
# 222              Jamie Raskin        RepRaskin               True
# 223            Jan Schakowsky    janschakowsky               True
# 224              Jared Golden        RepGolden                NaN
# 225             Jared Huffman       RepHuffman               True
# 226                Jason Crow     RepJasonCrow                NaN
# 227               Jason Smith    RepJasonSmith                NaN
# 228             Jay Obernolte     JayObernolte                NaN
# 229            Jeanne Shaheen   SenatorShaheen                NaN
# 230               Jeff Duncan    RepJeffDuncan                NaN
# 231          Jeff Fortenberry  JeffFortenberry                NaN
# 232              Jeff Merkley   SenJeffMerkley                NaN
# 233        Jefferson Van Drew  Congressman_JVD                NaN
# 234           Jennifer Wexton        RepWexton                NaN
# 235  Jenniffer Gonzalez-Colon     RepJenniffer                NaN
# 236            Jerrold Nadler   RepJerryNadler               True
# 237                Jerry Carl     RepJerryCarl                NaN
# 238            Jerry McNerney      RepMcNerney                NaN
# 239               Jerry Moran       JerryMoran                NaN
# 240              Jesus Garcia    RepChuyGarcia               True
# 241                 Jim Baird      RepJimBaird                NaN
# 242                 Jim Banks      RepJimBanks                NaN
# 243                Jim Cooper     repjimcooper                NaN
# 244                 Jim Costa      RepJimCosta                NaN
# 245              Jim Hagedorn      RepHagedorn                NaN
# 246                 Jim Himes          jahimes                NaN
# 247                Jim Jordan       Jim_Jordan                NaN
# 248              Jim Langevin      JimLangevin                NaN
# 249               Jimmy Gomez    RepJimmyGomez               True
# 250             Jimmy Panetta  RepJimmyPanetta               True
# 251            Joaquin Castro  JoaquinCastrotx                NaN
# 252           Jodey Arrington     RepArrington                NaN
# 253                 Jody Hice  CongressmanHice                NaN
# 254              Joe Courtney   RepJoeCourtney                NaN
# 255               Joe Manchin   Sen_JoeManchin                NaN
# 256               Joe Morelle    RepJoeMorelle               True
# 257                Joe Neguse     RepJoeNeguse               True
# 258                Joe Wilson     RepJoeWilson                NaN
# 259             John Barrasso  SenJohnBarrasso                NaN
# 260              John Boozman      JohnBoozman                NaN
# 261               John Carter      JudgeCarter                NaN
# 262               John Cornyn       JohnCornyn                NaN
# 263               John Curtis    RepJohnCurtis                NaN
# 264            John Garamendi     RepGaramendi                NaN
# 265         John Hickenlooper      SenatorHick                NaN
# 266               John Hoeven    SenJohnHoeven                NaN
# 267                John Joyce     RepJohnJoyce                NaN
# 268                John Katko     RepJohnKatko                NaN
# 269              John Kennedy   SenJohnKennedy                NaN
# 270               John Larson    RepJohnLarson                NaN
# 271            John Moolenaar     RepMoolenaar                NaN
# 272                 John Rose      RepJohnRose                NaN
# 273           John Rutherford  RepRutherfordFL                NaN
# 274             John Sarbanes      RepSarbanes                NaN
# 275                John Thune     SenJohnThune                NaN
# 276              John Yarmuth   RepJohnYarmuth               True
# 277                Jon Ossoff           ossoff                NaN
# 278                Jon Tester    SenatorTester                NaN
# 279                Joni Ernst     SenJoniErnst                NaN
# 280           Josh Gottheimer         RepJoshG                NaN
# 281               Josh Harder    RepJoshHarder                NaN
# 282               Josh Hawley         HawleyMO                NaN
# 283              Joyce Beatty        RepBeatty                NaN
# 284               Juan Vargas    RepJuanVargas               True
# 285                  Judy Chu       RepJudyChu               True
# 286            Julia Brownley      RepBrownley                NaN
# 287              Julia Letlow   RepJuliaLetlow                NaN
# 288                Kai Kahele        KaheleRep               True
# 289                Karen Bass     RepKarenBass               True
# 290               Kat Cammack    RepKatCammack                NaN
# 291           Katherine Clark        RepKClark               True
# 292             Kathleen Rice  RepKathleenRice                NaN
# 293              Kathy Castor     USRepKCastor                NaN
# 294             Kathy Manning      RepKManning                NaN
# 295              Katie Porter   RepKatiePorter               True
# 296               Kay Granger    RepKayGranger                NaN
# 297           Kelly Armstrong   RepArmstrongND                NaN
# 298                  Ken Buck       RepKenBuck                NaN
# 299               Ken Calvert       KenCalvert                NaN
# 300               Kevin Brady    RepKevinBrady                NaN
# 301              Kevin Cramer   SenKevinCramer                NaN
# 302                Kevin Hern     repkevinhern                NaN
# 303            Kevin McCarthy        GOPLeader                NaN
# 304               Kim Schrier    RepKimSchrier                NaN
# 305        Kirsten Gillibrand    SenGillibrand                NaN
# 306             Kurt Schrader      RepSchrader                NaN
# 307              Kweisi Mfume   RepKweisiMfume                NaN
# 308            Kyrsten Sinema    SenatorSinema                NaN
# 309              Lance Gooden      Lancegooden                NaN
# 310             Larry Bucshon  RepLarryBucshon                NaN
# 311            Lauren Boebert       RepBoebert                NaN
# 312          Lauren Underwood     RepUnderwood                NaN
# 313                Lee Zeldin     RepLeeZeldin                NaN
# 314             Linda Sanchez  RepLindaSanchez               True
# 315            Lindsey Graham  LindseyGrahamSC                NaN
# 316      Lisa Blunt Rochester           RepLBR               True
# 317              Lisa McClain   RepLisaMcClain                NaN
# 318            Lisa Murkowski    lisamurkowski                NaN
# 319                Liz Cheney     RepLizCheney                NaN
# 320           Lizzie Fletcher      RepFletcher                NaN
# 321             Lloyd Doggett  RepLloydDoggett               True
# 322             Lloyd Smucker       RepSmucker                NaN
# 323              Lois Frankel   RepLoisFrankel               True
# 324               Lori Trahan    RepLoriTrahan               True
# 325                Lou Correa     RepLouCorrea                NaN
# 326             Louie Gohmert  replouiegohmert                NaN
# 327     Lucille Roybal-Allard  RepRoybalAllard                NaN
# 328               Lucy McBath    RepLucyMcBath                NaN
# 329            Madeleine Dean          RepDean               True
# 330          Madison Cawthorn      RepCawthorn                NaN
# 331               Marc Veasey        RepVeasey                NaN
# 332              Marcia Fudge   RepMarciaFudge                NaN
# 333               Marco Rubio       marcorubio                NaN
# 334              Marcy Kaptur   RepMarcyKaptur                NaN
# 335           Margaret Hassan    SenatorHassan                NaN
# 336            Maria Cantwell  SenatorCantwell                NaN
# 337             Maria Salazar  RepMariaSalazar                NaN
# 338  Mariannette Miller-Meeks           RepMMM                NaN
# 339              Marie Newman   RepMarieNewman               True
# 340        Marilyn Strickland  RepStricklandWA                NaN
# 341         Mario Diaz-Balart          MarioDB                NaN
# 342    Marjorie Taylor Greene           RepMTG                NaN
# 343               Mark Amodei    MarkAmodeiNV2                NaN
# 344           Mark DeSaulnier    RepDeSaulnier               True
# 345                Mark Green     RepMarkGreen                NaN
# 346                Mark Kelly     SenMarkKelly                NaN
# 347                Mark Pocan     repmarkpocan               True
# 348               Mark Takano    RepMarkTakano               True
# 349               Mark Warner       MarkWarner                NaN
# 350          Markwayne Mullin        RepMullin                NaN
# 351          Marsha Blackburn  MarshaBlackburn                NaN
# 352           Martin Heinrich   MartinHeinrich                NaN
# 353          Mary Gay Scanlon           RepMGS               True
# 354               Mary Miller    RepMaryMiller                NaN
# 355           Matt Cartwright    RepCartwright               True
# 356                Matt Gaetz     RepMattGaetz                NaN
# 357         Matthew Rosendale     RepRosendale                NaN
# 358             Maxine Waters  RepMaxineWaters               True
# 359              Mazie Hirono      maziehirono                NaN
# 360            Michael Bennet    SenatorBennet                NaN
# 361           Michael Burgess  michaelcburgess                NaN
# 362             Michael Cloud       RepCloudTX                NaN
# 363             Michael Doyle   USRepMikeDoyle                NaN
# 364             Michael Guest  RepMichaelGuest                NaN
# 365            Michael McCaul        RepMcCaul                NaN
# 366       Michael San Nicolas  GuamCongressman                NaN
# 367             Michael Waltz    michaelgwaltz                NaN
# 368        Michelle Fischbach     RepFischbach                NaN
# 369            Michelle Steel         RepSteel                NaN
# 370                 Mike Bost          RepBost                NaN
# 371                Mike Braun     SenatorBraun                NaN
# 372                Mike Carey     RepMikeCarey                NaN
# 373                Mike Crapo        MikeCrapo                NaN
# 374            Mike Gallagher     RepGallagher                NaN
# 375               Mike Garcia    RepMikeGarcia                NaN
# 376              Mike Johnson   RepMikeJohnson                NaN
# 377                Mike Kelly      MikeKellyPA                NaN
# 378                  Mike Lee       SenMikeLee                NaN
# 379                Mike Levin     RepMikeLevin               True
# 380              Mike Quigley   RepMikeQuigley                NaN
# 381               Mike Rogers  RepMikeRogersAL                NaN
# 382               Mike Rounds    SenatorRounds                NaN
# 383              Mike Simpson  CongMikeSimpson                NaN
# 384             Mike Thompson      RepThompson                NaN
# 385               Mike Turner    RepMikeTurner                NaN
# 386            Mikie Sherrill      RepSherrill                NaN
# 387           Mitch McConnell     senatemajldr                NaN
# 388               Mitt Romney    SenatorRomney                NaN
# 389                 Mo Brooks      RepMoBrooks                NaN
# 390            Mondaire Jones      RepMondaire               True
# 391           Morgan Griffith     RepMGriffith                NaN
# 392                Nancy Mace     RepNancyMace                NaN
# 393              Nancy Pelosi    SpeakerPelosi                NaN
# 394          Nanette Barragan      RepBarragan               True
# 395                 Neal Dunn    DrNealDunnFL2                NaN
# 396        Nicole Malliotakis   RepMalliotakis                NaN
# 397           Nikema Williams        RepNikema               True
# 398              Norma Torres     NormaJTorres                NaN
# 399           Nydia Velazquez   NydiaVelazquez               True
# 400                Pat Fallon     RepPatFallon                NaN
# 401             Patrick Leahy     SenatorLeahy                NaN
# 402           Patrick McHenry   PatrickMcHenry                NaN
# 403            Patrick Toomey        SenToomey                NaN
# 404             Patty Murrary      PattyMurray                NaN
# 405                Paul Gosar         RepGosar                NaN
# 406                Paul Tonko     RepPaulTonko                NaN
# 407              Pete Aguilar   RepPeteAguilar                NaN
# 408             Pete Sessions     PeteSessions                NaN
# 409              Pete Stauber   RepPeteStauber                NaN
# 410             Peter DeFazio  RepPeterDeFazio               True
# 411              Peter Meijer        RepMeijer                NaN
# 412               Peter Welch       PeterWelch               True
# 413           Pramila Jayapal       RepJayapal               True
# 414       Raja Krishnamoorthi  CongressmanRaja                NaN
# 415              Ralph Norman   RepRalphNorman                NaN
# 416                 Rand Paul         RandPaul                NaN
# 417            Randy Feenstra      RepFeenstra                NaN
# 418               Randy Weber        TXRandy14                NaN
# 419           Raphael Warnock   SenatorWarnock                NaN
# 420             Rashida Tlaib       RepRashida               True
# 421             Raul Grijalva  RepRaulGrijalva               True
# 422                 Raul Ruiz    RepRaulRuizMD                NaN
# 423        Richard Blumenthal    SenBlumenthal                NaN
# 424              Richard Burr      SenatorBurr                NaN
# 425            Richard Durbin    SenatorDurbin                NaN
# 426            Richard Hudson    RepRichHudson                NaN
# 427              Richard Neal   RepRichardNeal                NaN
# 428            Richard Shelby        SenShelby                NaN
# 429                Rick Allen     RepRickAllen                NaN
# 430             Rick Crawford  RepRickCrawford                NaN
# 431               Rick Larsen    RepRickLarsen                NaN
# 432                Rick Scott     SenRickScott                NaN
# 433            Ritchie Torres       RepRitchie               True
# 434                 Ro Khanna      RepRoKhanna               True
# 435               Rob Portman    senrobportman                NaN
# 436           Robert Aderholt  Robert_Aderholt                NaN
# 437              Robert Casey      SenBobCasey                NaN
# 438              Robert Latta         boblatta                NaN
# 439              Robert Scott       BobbyScott                NaN
# 440            Robert Wittman       RobWittman                NaN
# 441               Robin Kelly    RepRobinKelly                NaN
# 442              Rodney Davis      RodneyDavis                NaN
# 443            Roger Marshall  SenatorMarshall                NaN
# 444              Roger Wicker    SenatorWicker                NaN
# 445            Roger Williams     RepRWilliams                NaN
# 446                 Ron Estes      RepRonEstes                NaN
# 447               Ron Johnson    SenRonJohnson                NaN
# 448                  Ron Kind       RepRonKind                NaN
# 449                Ron Wright     RepRonWright                NaN
# 450                 Ron Wyden         RonWyden                NaN
# 451             Ronny Jackson  RepRonnyJackson                NaN
# 452              Rosa DeLauro      rosadelauro               True
# 453                 Roy Blunt         RoyBlunt                NaN
# 454             Ruben Gallego  RepRubenGallego               True
# 455              Russ Fulcher   RepRussFulcher                NaN
# 456            Salud Carbajal      RepCarbajal                NaN
# 457                Sam Graves     RepSamGraves                NaN
# 458        Sanford Bishop Jr.    SanfordBishop                NaN
# 459               Sara Jacobs    RepSaraJacobs                NaN
# 460          Scott DesJarlais   DesJarlaisTN04                NaN
# 461          Scott Fitzgerald    RepFitzgerald                NaN
# 462            Scott Franklin      RepFranklin                NaN
# 463               Scott Perry    RepScottPerry                NaN
# 464              Scott Peters   RepScottPeters                NaN
# 465               Sean Casten        RepCasten                NaN
# 466      Sean Patrick Maloney   RepSeanMaloney                NaN
# 467              Seth Moulton      teammoulton                NaN
# 468            Sharice Davids        RepDavids                NaN
# 469        Sheila Jackson Lee   JacksonLeeTX18               True
# 470        Sheldon Whitehouse    SenWhitehouse                NaN
# 471            Shelley Capito        SenCapito                NaN
# 472             Sherrod Brown  SenSherrodBrown                NaN
# 473           Stacey Plaskett   StaceyPlaskett                NaN
# 474               Steny Hoyer      LeaderHoyer                NaN
# 475            Stephanie Bice          RepBice                NaN
# 476          Stephanie Murphy   RepStephMurphy                NaN
# 477             Stephen Lynch  RepStephenLynch                NaN
# 478              Steve Chabot   RepSteveChabot                NaN
# 479               Steve Cohen         RepCohen               True
# 480              Steve Daines      SteveDaines                NaN
# 481             Steve Scalise     SteveScalise                NaN
# 482             Steve Stivers  RepSteveStivers                NaN
# 483              Steve Womack  rep_stevewomack                NaN
# 484           Steven Horsford      RepHorsford               True
# 485            Steven Palazzo      CongPalazzo                NaN
# 486             Susan Collins   SenatorCollins                NaN
# 487                Susan Wild     RepSusanWild                NaN
# 488                 Susie Lee      RepSusieLee                NaN
# 489             Suzan DelBene       RepDelBene                NaN
# 490          Suzanne Bonamici      RepBonamici               True
# 491             Sylvia Garcia  RepSylviaGarcia               True
# 492             Tammy Baldwin   SenatorBaldwin                NaN
# 493           Tammy Duckworth     SenDuckworth                NaN
# 494                  Ted Budd       RepTedBudd                NaN
# 495                  Ted Cruz       SenTedCruz                NaN
# 496                Ted Deutch     RepTedDeutch                NaN
# 497                  Ted Lieu       RepTedLieu               True
# 498    Teresa Leger Fernandez      RepTeresaLF               True
# 499              Terri Sewell   RepTerriSewell                NaN
# 500               Thom Tillis    SenThomTillis                NaN
# 501             Thomas Carper    SenatorCarper                NaN
# 502             Thomas Massie  RepThomasMassie                NaN
# 503             Thomas Suozzi     RepTomSuozzi                NaN
# 504            Thomas Tiffany       RepTiffany                NaN
# 505              Tim Burchett   RepTimBurchett                NaN
# 506                 Tim Kaine         timkaine                NaN
# 507                  Tim Ryan       RepTimRyan                NaN
# 508                 Tim Scott  SenatorTimScott                NaN
# 509               Tim Walberg       RepWalberg                NaN
# 510                Tina Smith     SenTinaSmith                NaN
# 511                Todd Young     SenToddYoung                NaN
# 512                  Tom Cole      TomColeOK04                NaN
# 513                Tom Cotton     SenTomCotton                NaN
# 514                 Tom Emmer      RepTomEmmer                NaN
# 515            Tom Malinowski    RepMalinowski                NaN
# 516            Tom McClintock    RepMcClintock                NaN
# 517            Tom O'Halleran     RepOHalleran                NaN
# 518                  Tom Reed       RepTomReed                NaN
# 519                  Tom Rice       RepTomRice                NaN
# 520          Tommy Tuberville    SenTuberville                NaN
# 521             Tony Cardenas      RepCardenas                NaN
# 522             Tony Gonzales  RepTonyGonzales                NaN
# 523               Tracey Mann          RepMann                NaN
# 524               Trent Kelly    RepTrentKelly                NaN
# 525        Trey Hollingsworth          RepTrey                NaN
# 526            Troy Balderson     RepBalderson                NaN
# 527                Troy Nehls     RepTroyNehls                NaN
# 528               Val Demings    RepValDemings                NaN
# 529                Van Taylor     RepVanTaylor                NaN
# 530             Vern Buchanan     VernBuchanan                NaN
# 531          Veronica Escobar       RepEscobar               True
# 532          Vicente Gonzalez      RepGonzalez                NaN
# 533            Vicky Hartzler      RepHartzler                NaN
# 534           Victoria Spartz        RepSpartz                NaN
# 535             Virginia Foxx     virginiafoxx                NaN
# 536           Warren Davidson   WarrenDavidson                NaN
# 537           William Timmons       RepTimmons                NaN
# 538                 Young Kim      RepYoungKim                NaN
# 539             Yvette Clarke  RepYvetteClarke               True
# 540            Yvette Herrell       RepHerrell                NaN
# 541               Zoe Lofgren    RepZoeLofgren               True
#
#     new democratic coalition problem solvers caucus  \
# 0                       True                   True
# 1                        NaN                    NaN
# 2                       True                    NaN
# 3                       True                    NaN
# 4                        NaN                    NaN
# 5                        NaN                    NaN
# 6                        NaN                    NaN
# 7                       True                    NaN
# 8                        NaN                    NaN
# 9                        NaN                    NaN
# 10                       NaN                    NaN
# 11                       NaN                    NaN
# 12                       NaN                    NaN
# 13                       NaN                    NaN
# 14                       NaN                    NaN
# 15                       NaN                    NaN
# 16                      True                    NaN
# 17                       NaN                    NaN
# 18                      True                    NaN
# 19                       NaN                    NaN
# 20                       NaN                   True
# 21                       NaN                    NaN
# 22                       NaN                    NaN
# 23                       NaN                    NaN
# 24                       NaN                    NaN
# 25                       NaN                    NaN
# 26                      True                    NaN
# 27                       NaN                    NaN
# 28                      True                    NaN
# 29                      True                    NaN
# 30                       NaN                    NaN
# 31                       NaN                    NaN
# 32                      True                    NaN
# 33                       NaN                   True
# 34                       NaN                    NaN
# 35                       NaN                    NaN
# 36                       NaN                    NaN
# 37                       NaN                    NaN
# 38                       NaN                    NaN
# 39                       NaN                    NaN
# 40                       NaN                    NaN
# 41                       NaN                    NaN
# 42                       NaN                   True
# 43                       NaN                    NaN
# 44                       NaN                    NaN
# 45                       NaN                    NaN
# 46                       NaN                    NaN
# 47                       NaN                    NaN
# 48                       NaN                    NaN
# 49                       NaN                    NaN
# 50                       NaN                    NaN
# 51                      True                    NaN
# 52                       NaN                    NaN
# 53                       NaN                    NaN
# 54                       NaN                   True
# 55                      True                    NaN
# 56                       NaN                    NaN
# 57                       NaN                    NaN
# 58                       NaN                    NaN
# 59                       NaN                    NaN
# 60                       NaN                    NaN
# 61                       NaN                    NaN
# 62                       NaN                    NaN
# 63                       NaN                    NaN
# 64                       NaN                    NaN
# 65                       NaN                    NaN
# 66                      True                   True
# 67                       NaN                    NaN
# 68                       NaN                    NaN
# 69                      True                    NaN
# 70                      True                    NaN
# 71                       NaN                    NaN
# 72                       NaN                    NaN
# 73                       NaN                   True
# 74                       NaN                    NaN
# 75                       NaN                    NaN
# 76                       NaN                    NaN
# 77                       NaN                    NaN
# 78                       NaN                   True
# 79                       NaN                    NaN
# 80                       NaN                    NaN
# 81                       NaN                    NaN
# 82                       NaN                    NaN
# 83                       NaN                    NaN
# 84                      True                   True
# 85                       NaN                    NaN
# 86                       NaN                    NaN
# 87                       NaN                    NaN
# 88                       NaN                    NaN
# 89                      True                    NaN
# 90                       NaN                    NaN
# 91                      True                    NaN
# 92                       NaN                    NaN
# 93                       NaN                    NaN
# 94                      True                    NaN
# 95                       NaN                   True
# 96                       NaN                    NaN
# 97                       NaN                    NaN
# 98                      True                   True
# 99                      True                   True
# 100                      NaN                    NaN
# 101                      NaN                    NaN
# 102                      NaN                    NaN
# 103                      NaN                    NaN
# 104                     True                    NaN
# 105                      NaN                    NaN
# 106                      NaN                    NaN
# 107                      NaN                    NaN
# 108                      NaN                    NaN
# 109                     True                    NaN
# 110                      NaN                   True
# 111                      NaN                    NaN
# 112                      NaN                    NaN
# 113                      NaN                    NaN
# 114                      NaN                    NaN
# 115                      NaN                    NaN
# 116                      NaN                    NaN
# 117                      NaN                    NaN
# 118                      NaN                    NaN
# 119                      NaN                   True
# 120                      NaN                    NaN
# 121                      NaN                    NaN
# 122                      NaN                    NaN
# 123                      NaN                    NaN
# 124                     True                   True
# 125                      NaN                    NaN
# 126                      NaN                   True
# 127                      NaN                    NaN
# 128                      NaN                    NaN
# 129                      NaN                    NaN
# 130                      NaN                    NaN
# 131                      NaN                    NaN
# 132                     True                    NaN
# 133                     True                    NaN
# 134                      NaN                    NaN
# 135                     True                   True
# 136                      NaN                    NaN
# 137                      NaN                   True
# 138                      NaN                    NaN
# 139                      NaN                    NaN
# 140                     True                    NaN
# 141                     True                    NaN
# 142                      NaN                    NaN
# 143                     True                    NaN
# 144                      NaN                    NaN
# 145                      NaN                    NaN
# 146                      NaN                    NaN
# 147                      NaN                    NaN
# 148                      NaN                    NaN
# 149                      NaN                   True
# 150                     True                    NaN
# 151                      NaN                    NaN
# 152                      NaN                    NaN
# 153                     True                    NaN
# 154                      NaN                    NaN
# 155                      NaN                    NaN
# 156                      NaN                    NaN
# 157                      NaN                    NaN
# 158                      NaN                    NaN
# 159                      NaN                   True
# 160                      NaN                    NaN
# 161                      NaN                    NaN
# 162                      NaN                    NaN
# 163                     True                    NaN
# 164                     True                    NaN
# 165                      NaN                    NaN
# 166                      NaN                    NaN
# 167                     True                   True
# 168                      NaN                    NaN
# 169                      NaN                    NaN
# 170                     True                   True
# 171                      NaN                    NaN
# 172                      NaN                    NaN
# 173                      NaN                    NaN
# 174                      NaN                    NaN
# 175                      NaN                    NaN
# 176                     True                    NaN
# 177                      NaN                    NaN
# 178                      NaN                    NaN
# 179                      NaN                   True
# 180                      NaN                    NaN
# 181                      NaN                    NaN
# 182                      NaN                    NaN
# 183                      NaN                    NaN
# 184                      NaN                    NaN
# 185                      NaN                    NaN
# 186                     True                    NaN
# 187                      NaN                    NaN
# 188                      NaN                    NaN
# 189                      NaN                    NaN
# ...
# 332                         NaN                        NaN            NaN
# 333                         NaN                        NaN            NaN
# 334                         NaN                        NaN            NaN
# 335                         NaN                        NaN            NaN
# 336                         NaN                        NaN            NaN
# 337                        True                        NaN            NaN
# 338                        True                        NaN            NaN
# 339                         NaN                        NaN            NaN
# 340                         NaN                        NaN            NaN
# 341                        True                        NaN            NaN
# 342                         NaN                       True            NaN
# 343                        True                        NaN            NaN
# 344                         NaN                        NaN            NaN
# 345                         NaN                       True           True
# 346                         NaN                        NaN            NaN
# 347                         NaN                        NaN            NaN
# 348                         NaN                        NaN            NaN
# 349                         NaN                        NaN            NaN
# 350                         NaN                       True            NaN
# 351                         NaN                        NaN            NaN
# 352                         NaN                        NaN            NaN
# 353                         NaN                        NaN            NaN
# 354                         NaN                       True           True
# 355                         NaN                        NaN            NaN
# 356                         NaN                        NaN            NaN
# 357                         NaN                       True           True
# 358                         NaN                        NaN            NaN
# 359                         NaN                        NaN            NaN
# 360                         NaN                        NaN            NaN
# 361                        True                       True            NaN
# 362                         NaN                       True           True
# 363                         NaN                        NaN            NaN
# 364                         NaN                        NaN            NaN
# 365                        True                       True            NaN
# 366                         NaN                        NaN            NaN
# 367                         NaN                       True            NaN
# 368                         NaN                       True            NaN
# 369                        True                        NaN            NaN
# 370                        True                       True            NaN
# 371                         NaN                        NaN            NaN
# 372                         NaN                       True            NaN
# 373                         NaN                        NaN            NaN
# 374                        True                       True            NaN
# 375                         NaN                       True            NaN
# 376                         NaN                       True            NaN
# 377                         NaN                       True            NaN
# 378                         NaN                        NaN            NaN
# 379                         NaN                        NaN            NaN
# 380                         NaN                        NaN            NaN
# 381                         NaN                       True            NaN
# 382                         NaN                        NaN            NaN
# 383                         NaN                        NaN            NaN
# 384                         NaN                        NaN            NaN
# 385                        True                       True            NaN
# 386                         NaN                        NaN            NaN
# 387                         NaN                        NaN            NaN
# 388                         NaN                        NaN            NaN
# 389                         NaN                        NaN           True
# 390                         NaN                        NaN            NaN
# 391                         NaN                        NaN           True
# 392                        True                        NaN            NaN
# 393                         NaN                        NaN            NaN
# 394                         NaN                        NaN            NaN
# 395                         NaN                       True            NaN
# 396                        True                       True            NaN
# 397                         NaN                        NaN            NaN
# 398                         NaN                        NaN            NaN
# 399                         NaN                        NaN            NaN
# 400                         NaN                       True            NaN
# 401                         NaN                        NaN            NaN
# 402                         NaN                       True            NaN
# 403                         NaN                        NaN            NaN
# 404                         NaN                        NaN            NaN
# 405                         NaN                       True           True
# 406                         NaN                        NaN            NaN
# 407                         NaN                        NaN            NaN
# 408                         NaN                        NaN            NaN
# 409                        True                       True            NaN
# 410                         NaN                        NaN            NaN
# 411                        True                        NaN            NaN
# 412                         NaN                        NaN            NaN
# 413                         NaN                        NaN            NaN
# 414                         NaN                        NaN            NaN
# 415                         NaN                       True           True
# 416                         NaN                        NaN            NaN
# 417                         NaN                       True            NaN
# 418                         NaN                       True           True
# 419                         NaN                        NaN            NaN
# 420                         NaN                        NaN            NaN
# 421                         NaN                        NaN            NaN
# 422                         NaN                        NaN            NaN
# 423                         NaN                        NaN            NaN
# 424                         NaN                        NaN            NaN
# 425                         NaN                        NaN            NaN
# 426                         NaN                       True            NaN
# 427                         NaN                        NaN            NaN
# 428                         NaN                        NaN            NaN
# 429                         NaN                       True            NaN
# 430                         NaN                        NaN            NaN
# 431                         NaN                        NaN            NaN
# 432                         NaN                        NaN            NaN
# 433                         NaN                        NaN            NaN
# 434                         NaN                        NaN            NaN
# 435                         NaN                        NaN            NaN
# 436                         NaN                       True            NaN
# 437                         NaN                        NaN            NaN
# 438                         NaN                       True            NaN
# 439                         NaN                        NaN            NaN
# 440                         NaN                       True            NaN
# 441                         NaN                        NaN            NaN
# 442                        True                        NaN            NaN
# 443                         NaN                        NaN            NaN
# 444                         NaN                        NaN            NaN
# 445                         NaN                       True            NaN
# 446                         NaN                       True            NaN
# 447                         NaN                        NaN            NaN
# 448                         NaN                        NaN            NaN
# 449                         NaN                        NaN            NaN
# 450                         NaN                        NaN            NaN
# 451                         NaN                       True            NaN
# 452                         NaN                        NaN            NaN
# 453                         NaN                        NaN            NaN
# 454                         NaN                        NaN            NaN
# 455                         NaN                       True           True
# 456                         NaN                        NaN            NaN
# 457                         NaN                        NaN            NaN
# 458                         NaN                        NaN            NaN
# 459                         NaN                        NaN            NaN
# 460                         NaN                       True           True
# 461                         NaN                       True            NaN
# 462                         NaN                       True            NaN
# 463                         NaN                        NaN            NaN
# 464                         NaN                        NaN            NaN
# 465                         NaN                        NaN            NaN
# 466                         NaN                        NaN            NaN
# 467                         NaN                        NaN            NaN
# 468                         NaN                        NaN            NaN
# 469                         NaN                        NaN            NaN
# 470                         NaN                        NaN            NaN
# 471                         NaN                        NaN            NaN
# 472                         NaN                        NaN            NaN
# 473                         NaN                        NaN            NaN
# 474                         NaN                        NaN            NaN
# 475                         NaN                        NaN            NaN
# 476                         NaN                        NaN            NaN
# 477                         NaN                        NaN            NaN
# 478                         NaN                       True            NaN
# 479                         NaN                        NaN            NaN
# 480                         NaN                        NaN            NaN
# 481                         NaN                       True            NaN
# 482                         NaN                        NaN            NaN
# 483                        True                        NaN            NaN
# 484                         NaN                        NaN            NaN
# 485                         NaN                       True            NaN
# 486                         NaN                        NaN            NaN
# 487                         NaN                        NaN            NaN
# 488                         NaN                        NaN            NaN
# 489                         NaN                        NaN            NaN
# 490                         NaN                        NaN            NaN
# 491                         NaN                        NaN            NaN
# 492                         NaN                        NaN            NaN
# 493                         NaN                        NaN            NaN
# 494                         NaN                       True           True
# 495                         NaN                        NaN            NaN
# 496                         NaN                        NaN            NaN
# 497                         NaN                        NaN            NaN
# 498                         NaN                        NaN            NaN
# 499                         NaN                        NaN            NaN
# 500                         NaN                        NaN            NaN
# 501                         NaN                        NaN            NaN
# 502                         NaN                        NaN            NaN
# 503                         NaN                        NaN            NaN
# 504                         NaN                       True           True
# 505                         NaN                       True            NaN
# 506                         NaN                        NaN            NaN
# 507                         NaN                        NaN            NaN
# 508                         NaN                        NaN            NaN
# 509                         NaN                       True            NaN
# 510                         NaN                        NaN            NaN
# 511                         NaN                        NaN            NaN
# 512                         NaN                       True            NaN
# 513                         NaN                        NaN            NaN
# 514                         NaN                       True            NaN
# 515                         NaN                        NaN            NaN
# 516                         NaN                       True            NaN
# 517                         NaN                        NaN            NaN
# 518                         NaN                       True            NaN
# 519                        True                       True            NaN
# 520                         NaN                        NaN            NaN
# 521                         NaN                        NaN            NaN
# 522                         NaN                       True            NaN
# 523                         NaN                       True            NaN
# 524                         NaN                       True            NaN
# 525                         NaN                        NaN            NaN
# 526                        True                       True            NaN
# 527                         NaN                       True            NaN
# 528                         NaN                        NaN            NaN
# 529                         NaN                       True            NaN
# 530                         NaN                       True            NaN
# 531                         NaN                        NaN            NaN
# 532                         NaN                        NaN            NaN
# 533                         NaN                       True            NaN
# 534                         NaN                       True            NaN
# 535                         NaN                       True            NaN
# 536                         NaN                       True           True
# 537                         NaN                       True            NaN
# 538                        True                        NaN            NaN
# 539                         NaN                        NaN            NaN
# 540                         NaN                       True           True
# 541                         NaN                        NaN            NaN
