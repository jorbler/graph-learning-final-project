# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ### Caucus data

# %%
caucuses = pd.read_csv("data/data_archive/caucuses_117congress.csv")

# %%
progressive = [member for member in list(caucuses["Progressive Caucus"]) if type(member) == str]
new_democratic = [member for member in list(caucuses["New Democratic Coalition"]) if type(member) == str]
freedom = [member for member in list(caucuses["Freedom Caucus"]) if type(member) == str]
rep_gov_group = [member for member in list(caucuses["Republican Governance Group"]) if type(member) == str]
rep_study_committee = [member for member in list(caucuses["Republican Study Committee"]) if type(member) == str]
problem_solvers = [member for member in list(caucuses["Problem Solvers Caucus"]) if type(member) == str]

# %%
for item in [progressive, new_democratic, freedom, rep_gov_group, rep_study_committee, problem_solvers]:
    for i in range(len(item)):
            item[i] = item[i].strip()

# %%
data = {"Progressive Caucus":progressive, 
        "New Democratic Coalition":new_democratic,
        "Freedom Caucus":freedom,
        "Republican Governance Group":rep_gov_group,
        "Republican Study Committee":rep_study_committee,
        "Problem Solvers Caucus":problem_solvers}

# %%
with open("data/caucus_117.json", "w") as file:
    json.dump(data, file)

# %% [markdown]
# ### Members and Usernames

# %%
members = pd.read_csv("data/data_archive/117congress_members.csv")
members.head()
# Out:
#          First      Last           State       Party
# 0     Alma S.      Adams  North Carolina  Democratic
# 1   Robert B.   Aderholt         Alabama  Republican
# 2        Pete    Aguilar      California  Democratic
# 3     Rick W.      Allen         Georgia  Republican
# 4    Colin Z.     Allred           Texas  Democratic

# %%
usernames = pd.read_csv("data/data_archive/workbook_XMembers.csv")[["Last Name", "First Name", "Handle", "Handle.1"]]
usernames.head()
# Out:
#     Last Name First Name          Handle   Handle.1
# 0   Murkowski       Lisa   lisamurkowski        NaN
# 1    Sullivan        Dan  SenDanSullivan        NaN
# 2      Shelby    Richard              C.  SenShelby
# 3  Tuberville      Tommy   SenTuberville        NaN
# 4     Boozman       John     JohnBoozman        NaN

# %%
last_names = usernames["Last Name"]
first_names = usernames["First Name"]
handles1 = usernames["Handle"]
handles2 = usernames["Handle.1"]

# %%
actual_handles = []
full_names = []

for i in range(len(handles1)):
    if type(handles2[i]) == float:
        actual_handles += [handles1[i]]
        full_names += [(first_names[i] + " " + last_names[i])]
    else:
        actual_handles += [handles2[i]]
        full_names += [(first_names[i] + " " + last_names[i])]

# %%
data = {"name":full_names,
        "username":actual_handles}

# %%
data
# Out:
# {'name': ['Lisa Murkowski',
#   'Dan Sullivan',
#   'Richard Shelby',
#   'Tommy Tuberville',
#   'John Boozman',
#   'Tom Cotton',
#   'Mark Kelly',
#   'Kyrsten Sinema',
#   'Dianne Feinstein',
#   'Alex Padilla',
#   'Michael Bennet',
#   'John Hickenlooper',
#   'Richard Blumenthal',
#   'Christopher Murphy',
#   'Thomas Carper',
#   'Christopher Coons',
#   'Marco Rubio',
#   'Rick Scott',
#   'Jon Ossoff',
#   'Raphael Warnock',
#   'Mazie Hirono',
#   'Brian Schatz',
#   'Joni Ernst',
#   'Chuck Grassley',
#   'Mike Crapo',
#   'James Risch',
#   'Tammy Duckworth',
#   'Richard Durbin',
#   'Mike Braun',
#   'Todd Young',
#   'Roger Marshall',
#   'Jerry Moran',
#   'Mitch McConnell',
#   'Rand Paul',
#   'Bill Cassidy',
#   'John Kennedy',
#   'Edward Markey',
#   'Elizabeth Warren',
#   'Benjamin Cardin',
#   'Chris Van Hollen',
#   'Susan Collins',
#   'Angus King',
#   'Gary Peters',
#   'Debbie Stabenow',
#   'Amy Klobuchar',
#   'Tina Smith',
#   'Roy Blunt',
#   'Josh Hawley',
#   'Cindy Hyde-Smith',
#   'Roger Wicker',
#   'Steve Daines',
#   'Jon Tester',
#   'Richard Burr',
#   'Thom Tillis',
#   'Kevin Cramer',
#   'John Hoeven',
#   'Deb Fischer',
#   'Ben Sasse',
#   'Margaret Hassan',
#   'Jeanne Shaheen',
#   'Cory Booker',
#   'Bob Menendez',
#   'Martin Heinrich',
#   'Ben Lujan',
#   'Catherine Cortez Masto',
#   'Jacky Rosen',
#   'Kirsten Gillibrand',
#   'Charles Schumer',
#   'Sherrod Brown',
#   'Rob Portman',
#   'James Inhofe',
#   'James Lankford',
#   'Jeff Merkley',
#   'Ron Wyden',
#   'Robert Casey',
#   'Patrick Toomey',
#   'Jack Reed',
#   'Sheldon Whitehouse',
#   'Lindsey Graham',
#   'Tim Scott',
#   'Mike Rounds',
#   'John Thune',
#   'Marsha Blackburn',
#   'Bill Hagerty',
#   'John Cornyn',
#   'Ted Cruz',
#   'Mike Lee',
#   'Mitt Romney',
#   'Tim Kaine',
#   'Mark Warner',
#   'Patrick Leahy',
#   'Bernard Sanders',
#   'Maria Cantwell',
#   'Patty Murrary',
#   'Tammy Baldwin',
#   'Ron Johnson',
#   'Shelley Capito',
#   'Joe Manchin',
#   'John Barrasso',
#   'Cynthia Lummis',
#   'Don Young',
#   'Robert Aderholt',
#   'Mo Brooks',
#   'Jerry Carl',
#   'Barry Moore',
#   'Gary Palmer',
#   'Mike Rogers',
#   'Terri Sewell',
#   'Rick Crawford',
#   'French Hill',
#   'Bruce Westerman',
#   'Steve Womack',
#   'Amata Radewagen',
#   'Andy Biggs',
#   'Ruben Gallego',
#   'Paul Gosar',
#   'Raul Grijalva',
#   'Ann Kirkpatrick',
#   'Debbie Lesko',
#   "Tom O'Halleran",
#   'David Schweikert',
#   'Greg Stanton',
#   'Pete Aguilar',
#   'Nanette Barragan',
#   'Karen Bass',
#   'Ami Bera',
#   'Julia Brownley',
#   'Ken Calvert',
#   'Salud Carbajal',
#   'Tony Cardenas',
#   'Judy Chu',
#   'J. Correa',
#   'Jim Costa',
#   'Mark DeSaulnier',
#   'Anna Eshoo',
#   'John Garamendi',
#   'Mike Garcia',
#   'Jimmy Gomez',
#   'Josh Harder',
#   'Jared Huffman',
#   'Darrell Issa',
#   'Sara Jacobs',
#   'Ro Khanna',
#   'Young Kim',
#   'Doug LaMalfa',
#   'Barbara Lee',
#   'Mike Levin',
#   'Ted Lieu',
#   'Zoe Lofgren',
#   'Alan Lowenthal',
#   'Doris Matsui',
#   'Kevin McCarthy',
#   'Tom McClintock',
#   'Jerry McNerney',
#   'Grace Napolitano',
#   'Devin Nunes',
#   'Jay Obernolte',
#   'Jimmy Panetta',
#   'Nancy Pelosi',
#   'Scott Peters',
#   'Katie Porter',
#   'Lucille Roybal-Allard',
#   'Raul Ruiz',
#   'Linda Sanchez',
#   'Adam Schiff',
#   'Brad Sherman',
#   'Jackie Speier',
#   'Michelle Steel',
#   'Eric Swalwell',
#   'Mark Takano',
#   'Mike Thompson',
#   'Norma Torres',
#   'David Valadao',
#   'Juan Vargas',
#   'Maxine Waters',
#   'Lauren Boebert',
#   'Ken Buck',
#   'Jason Crow',
#   'Diana DeGette',
#   'Doug Lamborn',
#   'Joe Neguse',
#   'Ed Perlmutter',
#   'Joe Courtney',
#   'Rosa DeLauro',
#   'Jahana Hayes',
#   'Jim Himes',
#   'John Larson',
#   'Eleanor Norton',
#   'Lisa Blunt Rochester',
#   'Gus Bilirakis',
#   'Vern Buchanan',
#   'Kat Cammack',
#   'Kathy Castor',
#   'Charlie Crist',
#   'Val Demings',
#   'Ted Deutch',
#   'Mario Diaz-Balart',
#   'Byron Donalds',
#   'Neal Dunn',
#   'Lois Frankel',
#   'C. Franklin',
#   'Matt Gaetz',
#   'Carlos Gimenez',
#   'Alcee Hastings',
#   'Al Lawson',
#   'Brian Mast',
#   'Stephanie Murphy',
#   'Bill Posey',
#   'John Rutherford',
#   'Maria Salazar',
#   'Darren Soto',
#   'W. Steube',
#   'Michael Waltz',
#   'Debbie Wasserman Schultz',
#   'Daniel Webster',
#   'Frederica Wilson',
#   'Rick Allen',
#   'Sanford Bishop Jr.',
#   'Carolyn Bourdeaux',
#   'Buddy Carter',
#   'Andrew Clyde',
#   'A. Ferguson',
#   'Majorie Greene',
#   'Jody Hice',
#   'Henry Johnson',
#   'Barry Loudermilk',
#   'Lucy McBath',
#   'Austin Scott',
#   'David Scott',
#   'Nikema Williams',
#   'Michael San Nicolas',
#   'Ed Case',
#   "Kaiali'i Kahele",
#   'Cindy Axne',
#   'Randy Feenstra',
#   'Ashley Hinson',
#   'Mariannette Miller-Meeks',
#   'Russ Fulcher',
#   'Mike Simpson',
#   'Mike Bost',
#   'Cheri Bustos',
#   'Sean Casten',
#   'Danny Davis',
#   'Rodney Davis',
#   'Bill Foster',
#   'Jesus Garcia',
#   'Robin Kelly',
#   'Adam Kinzinger',
#   'Raja Krishnamoorthi',
#   'Darin LaHood',
#   'Marie Newman',
#   'Mike Quigley',
#   'Bobby Rush',
#   'Jan Schakowsky',
#   'Bradley Schneider',
#   'Lauren Underwood',
#   'Jim Baird',
#   'Jim Banks',
#   'Larry Bucshon',
#   'Andr� Carson',
#   'Trey Hollingsworth',
#   'Frank Mrvan',
#   'Greg Pence',
#   'Victoria Spartz',
#   'Jackie Walorski',
#   'Sharice Davids',
#   'Ron Estes',
#   'Jake LaTurner',
#   'Tracey Mann',
#   'Andy Barr',
#   'James Comer',
#   'S. Guthrie',
#   'Thomas Massie',
#   'Harold Rogers',
#   'John Yarmuth',
#   'Garret Graves',
#   'Clay Higgins',
#   'Mike Johnson',
#   'Steve Scalise',
#   'Jake Auchincloss',
#   'Katherine Clark',
#   'William Keating',
#   'Stephen Lynch',
#   'James McGovern',
#   'Seth Moulton',
#   'Richard Neal',
#   'Ayanna Pressley',
#   'Lori Trahan',
#   'Anthony Brown',
#   'Andy Harris',
#   'Steny Hoyer',
#   'Kweisi Mfume',
#   'Jamie Raskin',
#   'C. Ruppersberger',
#   'John Sarbanes',
#   'David Trone',
#   'Jared Golden',
#   'Chellie Pingree',
#   'Jack Bergman',
#   'Debbie Dingell',
#   'Bill Huizenga',
#   'Dan Kildee',
#   'Brenda Lawrence',
#   'Andy Levin',
#   'Lisa McClain',
#   'Peter Meijer',
#   'John Moolenaar',
#   'Elissa Slotkin',
#   'Haley Stevens',
#   'Rashida Tlaib',
#   'Fred Upton',
#   'Tim Walberg',
#   'Angie Craig',
#   'Tom Emmer',
#   'Michelle Fischbach',
#   'Jim Hagedorn',
#   'Betty McCollum',
#   'Ilhan Omar',
#   'Dean Phillips',
#   'Pete Stauber',
#   'Cori Bush',
#   'Emanuel Cleaver',
#   'Sam Graves',
#   'Vicky Hartzler',
#   'Billy Long',
#   'Blaine Luetkemeyer',
#   'Jason Smith',
#   'Ann Wagner',
#   'Gregorio Sablan',
#   'Michael Guest',
#   'Trent Kelly',
#   'Steven Palazzo',
#   'Bernie Thompson',
#   'Matthew Rosendale',
#   'Alma Adams',
#   'Dan Bishop',
#   'Ted Budd',
#   'G.K. Butterfield',
#   'Madison Cawthorn',
#   'Virginia Foxx',
#   'Richard Hudson',
#   'Kathy Manning',
#   'Patrick McHenry',
#   'Gregory Murphy',
#   'David Price',
#   'Deborah Ross',
#   'David Rouzer',
#   'Kelly Armstrong',
#   'Don Bacon',
#   'Jeff Fortenberry',
#   'Adrian Smith',
#   'Ann Kuster',
#   'Chris Pappas',
#   'Josh Gottheimer',
#   'Andy Kim',
#   'Tom Malinowski',
#   'Donald Norcross',
#   'Frank Pallone Jr.',
#   'Bill Pascrell Jr.',
#   'Donald Payne Jr.',
#   'Mikie Sherrill',
#   'Albio Sires',
#   'Chris Smith',
#   'Jefferson Van Drew',
#   'Bonnie Watson Coleman',
#   'Debra Haaland',
#   'Yvette Herrell',
#   'Teresa Leger Fernandez',
#   'Mark Amodei',
#   'Steven Horsford',
#   'Susie Lee',
#   'Dina Titus',
#   'Jamaal Bowman',
#   'Yvette Clarke',
#   'Antonio Delgado',
#   'Adriano Espaillat',
#   'Andrew Garbarino',
#   'Brian Higgins',
#   'Chris Jacobs',
#   'Hakeem Jeffries',
#   'Mondaire Jones',
#   'John Katko',
#   'Nicole Malliotakis',
#   'Carolyn Maloney',
#   'Sean Maloney',
#   'Gregory Meeks',
#   'Grace Meng',
#   'Jospeh Morelle',
#   'Jerrold Nadler',
#   'Alexandria Ocasio-Cortez',
#   'Tom Reed',
#   'Kathleen Rice',
#   'Elise Stefanik',
#   'Thomas Suozzi',
#   'Paul Tonko',
#   'Ritchie Torres',
#   'Nydia Velazquez',
#   'Lee Zeldin',
#   'Troy Balderson',
#   'Joyce Beatty',
#   'Steve Chabot',
#   'Warren Davidson',
#   'Marcia Fudge',
#   'Bob Gibbs',
#   'Anthony Gonzalez',
#   'Bill Johnson',
#   'Jim Jordan',
#   'David Joyce',
#   'Marcy Kaptur',
#   'Robert Latta',
#   'Tim Ryan',
#   'Steve Stivers',
#   'Mike Turner',
#   'Brad Wenstrup',
#   'Stephanie Bice',
#   'Tom Cole',
#   'Kevin Hern',
#   'Frank Lucas',
#   'Markwayne Mullin',
#   'Cliff Bentz',
#   'Earl Blumenauer',
#   'Suzanne Bonamici',
#   'Peter DeFazio',
#   'Kurt Schrader',
#   'Brendan Boyle',
#   'Matt Cartwright',
#   'Madeleine Dean',
#   'Michael Doyle',
#   'Dwight Evans',
#   'Brian Fitzpatrick',
#   'Chrissy Houlahan',
#   'John Joyce',
#   'Fred Keller',
#   'Mike Kelly',
#   'Conor Lamb',
#   'Daniel Meuser',
#   'Scott Perry',
#   'Guy Reschenthaler',
#   'Mary Scanlon',
#   'Lloyd Smucker',
#   'Glenn Thompson',
#   'Susan Wild',
#   'Jenniffer Gonzalez-Colon',
#   'David Cicilline',
#   'Jim Langevin',
#   'James Clyburn',
#   'Jeff Duncan',
#   'Nancy Mace',
#   'Ralph Norman',
#   'Tom Rice',
#   'William Timmons',
#   'Joe Wilson',
#   'Dusty Johnson',
#   'Tim Burchett',
#   'Steve Cohen',
#   'Jim Cooper',
#   'Scott DesJarlais',
#   'Chuck Fleischmann',
#   'Mark Green',
#   'Diana Harshbarger',
#   'David Kustoff',
#   'John Rose',
#   'Colin Allred',
#   'Jodey Arrington',
#   'Brian Babin',
#   'Kevin Brady',
#   'Michael Burgess',
#   'John Carter',
#   'Joaquin Castro',
#   'Michael Cloud',
#   'Dan Crenshaw',
#   'Henry Cuellar',
#   'Lloyd Doggett',
#   'Veronica Escobar',
#   'Pat Fallon',
#   'Lizzie Fletcher',
#   'Sylvia Garcia',
#   'Louie Gohmert',
#   'Tony Gonzales',
#   'Vicente Gonzalez',
#   'Lance Gooden',
#   'Kay Granger',
#   'Al Green',
#   'Sheila Jackson Lee',
#   'Ronny Jackson',
#   'Eddie Johnson',
#   'Michael McCaul',
#   'Troy Nehls',
#   'August Pfluger',
#   'Chip Roy',
#   'Pete Sessions',
#   'Van Taylor',
#   'Beth Van Duyne',
#   'Marc Veasey',
#   'Filemon Vela',
#   'Randy Weber',
#   'Roger Williams',
#   'Ron Wright',
#   'John Curtis',
#   'Blake Moore',
#   'Burgess Owens',
#   'Chris Stewart',
#   'Don Beyer',
#   'Ben Cline',
#   'Gerald Connolly',
#   'Bob Good',
#   'Morgan Griffith',
#   'Elaine Luria',
#   'A. McEachin',
#   'Robert Scott',
#   'Abigail Spanberger',
#   'Jennifer Wexton',
#   'Robert Wittman',
#   'Stacey Plaskett',
#   'Peter Welch',
#   'Suzan DelBene',
#   'Jaime Herrera Butler',
#   'Pramila Jayapal',
#   'Derek Kilmer',
#   'Rick Larsen',
#   'Dan Newhouse',
#   'Cathy Rodgers',
#   'Kim Schrier',
#   'Adam Smith',
#   'Marilyn Strickland',
#   'Scott Fitzgerald',
#   'Mike Gallagher',
#   'Glenn Grothman',
#   'Ron Kind',
#   'Gwen Moore',
#   'Mark Pocan',
#   'Bryan Steil',
#   'Thomas Tiffany',
#   'David McKinley',
#   'Carol Miller',
#   'Mary Miller',
#   'Alex Mooney',
#   'Liz Cheney'],
#  'username': ['lisamurkowski',
#   'SenDanSullivan',
#   'SenShelby',
#   'SenTuberville',
#   'JohnBoozman',
#   'SenTomCotton',
#   'SenMarkKelly',
#   'SenatorSinema',
#   'SenFeinstein',
#   'SenAlexPadilla',
#   'SenatorBennet',
#   'SenatorHick',
#   'SenBlumenthal',
#   'ChrisMurphyCT',
#   'SenatorCarper',
#   'ChrisCoons',
#   'marcorubio',
#   'SenRickScott',
#   'ossoff',
#   'SenatorWarnock',
#   'maziehirono',
#   'SenBrianSchatz',
#   'SenJoniErnst',
#   'ChuckGrassley',
#   'MikeCrapo',
#   'SenatorRisch',
#   'SenDuckworth',
#   'SenatorDurbin',
#   'SenatorBraun',
#   'SenToddYoung',
#   'SenatorMarshall',
#   'JerryMoran',
#   'senatemajldr',
#   'RandPaul',
#   'SenBillCassidy',
#   'SenJohnKennedy',
#   'SenMarkey',
#   'SenWarren',
#   'SenatorCardin',
#   'ChrisVanHollen',
#   'SenatorCollins',
#   'Jr.',
#   'SenGaryPeters',
#   'SenStabenow',
#   'SenAmyKlobuchar',
#   'SenTinaSmith',
#   'RoyBlunt',
#   'HawleyMO',
#   'SenHydeSmith',
#   'SenatorWicker',
#   'SteveDaines',
#   'SenatorTester',
#   'SenatorBurr',
#   'SenThomTillis',
#   'SenKevinCramer',
#   'SenJohnHoeven',
#   'SenatorFischer',
#   'SenSasse',
#   'SenatorHassan',
#   'SenatorShaheen',
#   'CoryBooker',
#   'SenatorMenendez',
#   'MartinHeinrich',
#   'SenatorLujan',
#   'SenCortezMasto',
#   'SenJackyRosen',
#   'SenGillibrand',
#   'SenSchumer',
#   'SenSherrodBrown',
#   'senrobportman',
#   'JimInhofe',
#   'SenatorLankford',
#   'SenJeffMerkley',
#   'RonWyden',
#   'Jr.',
#   'SenToomey',
#   'SenJackReed',
#   'SenWhitehouse',
#   'LindseyGrahamSC',
#   'SenatorTimScott',
#   'SenatorRounds',
#   'SenJohnThune',
#   'MarshaBlackburn',
#   'SenatorHagerty',
#   'JohnCornyn',
#   'SenTedCruz',
#   'SenMikeLee',
#   'SenatorRomney',
#   'timkaine',
#   'MarkWarner',
#   'SenatorLeahy',
#   'SenSanders',
#   'SenatorCantwell',
#   'PattyMurray',
#   'SenatorBaldwin',
#   'SenRonJohnson',
#   'SenCapito',
#   nan,
#   'SenJohnBarrasso',
#   'SenLummis',
#   'repdonyoung',
#   'Robert_Aderholt',
#   'RepMoBrooks',
#   'RepJerryCarl',
#   'RepBarryMoore',
#   'USRepGaryPalmer',
#   'RepMikeRogersAL',
#   'RepTerriSewell',
#   'RepRickCrawford',
#   'RepFrenchHill',
#   'RepWesterman',
#   'rep_stevewomack',
#   'RepAmata',
#   'RepAndyBiggsAZ',
#   'RepRubenGallego',
#   'RepGosar',
#   'RepRaulGrijalva',
#   'RepKirkpatrick',
#   'RepDLesko',
#   'RepOHalleran',
#   'RepDavid',
#   'RepGregStanton',
#   'RepPeteAguilar',
#   'RepBarragan',
#   'RepKarenBass',
#   'RepBera',
#   'RepBrownley',
#   'KenCalvert',
#   'RepCarbajal',
#   'RepCardenas',
#   'RepJudyChu',
#   'RepLouCorrea',
#   'RepJimCosta',
#   'RepDeSaulnier',
#   'RepAnnaEshoo',
#   'RepGaramendi',
#   'RepMikeGarcia',
#   'RepJimmyGomez',
#   'RepJoshHarder',
#   'RepHuffman',
#   'repdarrellissa',
#   'RepSaraJacobs',
#   'RepRoKhanna',
#   'RepYoungKim',
#   'RepLaMalfa',
#   'RepBarbaraLee',
#   'RepMikeLevin',
#   'RepTedLieu',
#   'RepZoeLofgren',
#   'RepLowenthal',
#   'DorisMatsui',
#   'GOPLeader',
#   'RepMcClintock',
#   'RepMcNerney',
#   'gracenapolitano',
#   'RepDevinNunes',
#   'JayObernolte',
#   'RepJimmyPanetta',
#   'SpeakerPelosi',
#   'RepScottPeters',
#   'RepKatiePorter',
#   'RepRoybalAllard',
#   'RepRaulRuizMD',
#   'RepLindaSanchez',
#   'RepAdamSchiff',
#   'BradSherman',
#   'RepSpeier',
#   'RepSteel',
#   'RepSwalwell',
#   'RepMarkTakano',
#   'RepThompson',
#   'NormaJTorres',
#   'RepDavidValadao',
#   'RepJuanVargas',
#   'RepMaxineWaters',
#   'RepBoebert',
#   'RepKenBuck',
#   'RepJasonCrow',
#   'RepDianaDeGette',
#   'RepDLamborn',
#   'RepJoeNeguse',
#   'RepPerlmutter',
#   'RepJoeCourtney',
#   'rosadelauro',
#   'RepJahanaHayes',
#   'jahimes',
#   'RepJohnLarson',
#   'EleanorNorton',
#   'RepLBR',
#   'RepGusBilirakis',
#   'VernBuchanan',
#   'RepKatCammack',
#   'USRepKCastor',
#   'RepCharlieCrist',
#   'RepValDemings',
#   'RepTedDeutch',
#   'MarioDB',
#   'RepDonaldsPress',
#   'DrNealDunnFL2',
#   'RepLoisFrankel',
#   'RepFranklin',
#   'RepMattGaetz',
#   'RepCarlos',
#   'RepHastingsFL',
#   'RepAlLawsonJr',
#   'RepBrianMast',
#   'RepStephMurphy',
#   'congbillposey',
#   'RepRutherfordFL',
#   'RepMariaSalazar',
#   'RepDarrenSoto',
#   'RepGregSteube',
#   'michaelgwaltz',
#   'RepDWStweets',
#   'RepWebster',
#   'RepWilson',
#   'RepRickAllen',
#   'SanfordBishop',
#   'RepBourdeaux',
#   'RepBuddyCarter',
#   'GA',
#   'RepDrewFerguson',
#   'RepMTG',
#   'CongressmanHice',
#   'Hank',
#   'RepLoudermilk',
#   'RepLucyMcBath',
#   'AustinScottGA08',
#   'repdavidscott',
#   'RepNikema',
#   'GuamCongressman',
#   'RepEdCase',
#   'KaheleRep',
#   'RepCindyAxne',
#   'RepFeenstra',
#   'RepAshleyHinson',
#   'RepMMM',
#   'RepRussFulcher',
#   'CongMikeSimpson',
#   'RepBost',
#   'RepCheri',
#   'RepCasten',
#   'RepDannyDavis',
#   'RodneyDavis',
#   'RepBillFoster',
#   'RepChuyGarcia',
#   'RepRobinKelly',
#   'RepKinzinger',
#   'CongressmanRaja',
#   'RepLaHood',
#   'RepMarieNewman',
#   'RepMikeQuigley',
#   'RepBobbyRush',
#   'janschakowsky',
#   'RepSchneider',
#   'RepUnderwood',
#   'RepJimBaird',
#   'RepJimBanks',
#   'RepLarryBucshon',
#   'RepAndreCarson',
#   'RepTrey',
#   'RepMrvan',
#   'RepGregPence',
#   'RepSpartz',
#   'RepWalorski',
#   'RepDavids',
#   'RepRonEstes',
#   'RepLaTurner',
#   'RepMann',
#   'RepAndyBarr',
#   'RepJamesComer',
#   'RepGuthrie',
#   'RepThomasMassie',
#   'RepHalRogers',
#   'RepJohnYarmuth',
#   'RepGarretGraves',
#   'RepClayHiggins',
#   'RepMikeJohnson',
#   'SteveScalise',
#   'RepAuchincloss',
#   'RepKClark',
#   'USRepKeating',
#   'RepStephenLynch',
#   'RepMcGovern',
#   'teammoulton',
#   'RepRichardNeal',
#   'RepPressley',
#   'RepLoriTrahan',
#   'RepAnthonyBrown',
#   'RepAndyHarrisMD',
#   'LeaderHoyer',
#   'RepKweisiMfume',
#   'RepRaskin',
#   'Dutch',
#   'RepSarbanes',
#   'RepDavidTrone',
#   'RepGolden',
#   'chelliepingree',
#   'RepJackBergman',
#   'RepDebDingell',
#   'RepHuizenga',
#   'RepDanKildee',
#   'RepLawrence',
#   'RepAndyLevin',
#   'RepLisaMcClain',
#   'RepMeijer',
#   'RepMoolenaar',
#   'RepSlotkin',
#   'RepHaleyStevens',
#   'RepRashida',
#   'RepFredUpton',
#   'RepWalberg',
#   'RepAngieCraig',
#   'RepTomEmmer',
#   'RepFischbach',
#   'RepHagedorn',
#   'BettyMcCollum04',
#   'Ilhan',
#   'RepDeanPhillips',
#   'RepPeteStauber',
#   'RepCori',
#   'repcleaver',
#   'RepSamGraves',
#   'RepHartzler',
#   'USRepLong',
#   'RepBlaine',
#   'RepJasonSmith',
#   'RepAnnWagner',
#   'Kilili_Sablan',
#   'RepMichaelGuest',
#   'RepTrentKelly',
#   'CongPalazzo',
#   'BennieGThompson',
#   'RepRosendale',
#   'RepAdams',
#   'RepDanBishop',
#   'RepTedBudd',
#   'GKButterfield',
#   'RepCawthorn',
#   'virginiafoxx',
#   'RepRichHudson',
#   'RepKManning',
#   'PatrickMcHenry',
#   'RepGregMurphy',
#   'RepDavidEPrice',
#   'RepDeborahRoss',
#   'RepDavidRouzer',
#   'RepArmstrongND',
#   'RepDonBacon',
#   'JeffFortenberry',
#   'RepAdrianSmith',
#   'RepAnnieKuster',
#   'RepChrisPappas',
#   'RepJoshG',
#   'RepAndyKimNJ',
#   'RepMalinowski',
#   'DonaldNorcross',
#   'FrankPallone',
#   'BillPascrell',
#   'RepDonaldPayne',
#   'RepSherrill',
#   'RepSires',
#   'R',
#   'R',
#   'RepBonnie',
#   'RepDebHaaland',
#   'RepHerrell',
#   'RepTeresaLF',
#   'MarkAmodeiNV2',
#   'RepHorsford',
#   'RepSusieLee',
#   'repdinatitus',
#   'RepBowman',
#   'RepYvetteClarke',
#   'repdelgado',
#   'RepEspaillat',
#   'RepGarbarino',
#   'RepBrianHiggins',
#   'RepJacobs',
#   'RepJeffries',
#   'RepMondaire',
#   'RepJohnKatko',
#   'RepMalliotakis',
#   'RepMaloney',
#   'RepSeanMaloney',
#   'RepGregoryMeeks',
#   'RepGraceMeng',
#   'RepJoeMorelle',
#   'RepJerryNadler',
#   'RepAOC',
#   'RepTomReed',
#   'RepKathleenRice',
#   'RepStefanik',
#   'RepTomSuozzi',
#   'RepPaulTonko',
#   'RepRitchie',
#   'NydiaVelazquez',
#   'RepLeeZeldin',
#   'RepBalderson',
#   'RepBeatty',
#   'RepSteveChabot',
#   'WarrenDavidson',
#   'RepMarciaFudge',
#   'RepBobGibbs',
#   'RepAGonzalez',
#   'RepBillJohnson',
#   'Jim_Jordan',
#   'RepDaveJoyce',
#   'RepMarcyKaptur',
#   'boblatta',
#   'RepTimRyan',
#   'RepSteveStivers',
#   'RepMikeTurner',
#   'RepBradWenstrup',
#   'RepBice',
#   'TomColeOK04',
#   'repkevinhern',
#   'RepFrankLucas',
#   'RepMullin',
#   'RepBentz',
#   'repblumenauer',
#   'RepBonamici',
#   'RepPeterDeFazio',
#   'RepSchrader',
#   'CongBoyle',
#   'RepCartwright',
#   'RepDean',
#   'USRepMikeDoyle',
#   'RepDwightEvans',
#   'RepBrianFitz',
#   'RepHoulahan',
#   'RepJohnJoyce',
#   'RepFredKeller',
#   'MikeKellyPA',
#   'RepConorLamb',
#   'RepMeuser',
#   'RepScottPerry',
#   'GReschenthaler',
#   'RepMGS',
#   'RepSmucker',
#   'CongressmanGT',
#   'RepSusanWild',
#   'RepJenniffer',
#   'RepCicilline',
#   'JimLangevin',
#   'WhipClyburn',
#   'RepJeffDuncan',
#   'RepNancyMace',
#   'RepRalphNorman',
#   'RepTomRice',
#   'RepTimmons',
#   'RepJoeWilson',
#   'RepDustyJohnson',
#   'RepTimBurchett',
#   'RepCohen',
#   'repjimcooper',
#   'DesJarlaisTN04',
#   'RepChuck',
#   'RepMarkGreen',
#   'RepHarshbarger',
#   'RepDavidKustoff',
#   'RepJohnRose',
#   'RepColinAllred',
#   'RepArrington',
#   'RepBrianBabin',
#   'RepKevinBrady',
#   'michaelcburgess',
#   'JudgeCarter',
#   'JoaquinCastrotx',
#   'RepCloudTX',
#   'RepDanCrenshaw',
#   'RepCuellar',
#   'RepLloydDoggett',
#   'RepEscobar',
#   'RepPatFallon',
#   'RepFletcher',
#   'RepSylviaGarcia',
#   'replouiegohmert',
#   'RepTonyGonzales',
#   'RepGonzalez',
#   'R',
#   'RepKayGranger',
#   'RepAlGreen',
#   'JacksonLeeTX18',
#   'RepRonnyJackson',
#   'RepEBJ',
#   'RepMcCaul',
#   'RepTroyNehls',
#   'RepPfluger',
#   'RepChipRoy',
#   'PeteSessions',
#   'RepVanTaylor',
#   'RepBethVanDuyne',
#   'RepVeasey',
#   'RepFilemonVela',
#   'TXRandy14',
#   'RepRWilliams',
#   'RepRonWright',
#   'RepJohnCurtis',
#   'RepBlakeMoore',
#   'RepBurgessOwens',
#   'RepChrisStewart',
#   'RepDonBeyer',
#   'RepBenCline',
#   'Gerry',
#   'RepBobGood',
#   'RepMGriffith',
#   'RepElaineLuria',
#   'RepMcEachin',
#   'BobbyScott',
#   'RepSpanberger',
#   'RepWexton',
#   'RobWittman',
#   'StaceyPlaskett',
#   'PeterWelch',
#   'RepDelBene',
#   'HerreraBeutler',
#   'RepJayapal',
#   'RepDerekKilmer',
#   'RepRickLarsen',
#   'RepNewhouse',
#   'cathymcmorris',
#   'RepKimSchrier',
#   'RepAdamSmith',
#   'RepStricklandWA',
#   'RepFitzgerald',
#   'RepGallagher',
#   'RepGrothman',
#   'RepRonKind',
#   'RepGwenMoore',
#   'repmarkpocan',
#   'RepBryanSteil',
#   'RepTiffany',
#   'RepMcKinley',
#   'RepCarolMiller',
#   'RepMaryMiller',
#   'RepAlexMooney',
#   'RepLizCheney']}

# %%
names_handles = pd.DataFrame(data = {"name":full_names, "username":actual_handles})

# %%
names_handles.to_csv("data/member_handles.csv", index = False)

# %% [markdown]
# ### Merging DFs

# %%
pd.set_option("display.max_rows", None)

# %%
with open("data/caucus_117.json", "r") as file:
    caucuses = json.load(file)

progressive = caucuses["Progressive Caucus"]
new_democratic = caucuses["New Democratic Coalition"]
problem_solvers = caucuses["Problem Solvers Caucus"]
rep_gov_group = caucuses["Republican Governance Group"]
rep_study_com = caucuses["Republican Study Committee"]
freedom = caucuses["Freedom Caucus"]

# %%
members = pd.read_csv("data/member_handles.csv")
members.head(5)
# Out:
#                name        username
# 0    Lisa Murkowski   lisamurkowski
# 1      Dan Sullivan  SenDanSullivan
# 2    Richard Shelby       SenShelby
# 3  Tommy Tuberville   SenTuberville
# 4      John Boozman     JohnBoozman

# %%
prog_df = pd.DataFrame(data = {"name":progressive, "progressive caucus":[True]*len(progressive)})
new_dem_df = pd.DataFrame(data = {"name":new_democratic, "new democratic coalition":[True]*len(new_democratic)})
prob_solvers_df = pd.DataFrame(data = {"name":problem_solvers, "problem solvers caucus":[True]*len(problem_solvers)})
rep_gov_df = pd.DataFrame(data = {"name":rep_gov_group, "republican governance group":[True]*len(rep_gov_group)})
rep_study_df = pd.DataFrame(data = {"name":rep_study_com, "republican study committee":[True]*len(rep_study_com)})
freedom_df = pd.DataFrame(data = {"name":freedom, "freedom caucus":[True]*len(freedom)})

# %%
#members = pd.merge(members, prog_df, how = "left", on = "name")
#members = pd.merge(members, new_dem_df, how = "left", on = "name")
#members = pd.merge(members, prob_solvers_df, how = "left", on = "name")
#members = pd.merge(members, rep_gov_df, how = "left", on = "name")
members = pd.merge(members, rep_study_df, how = "outer", on = "name")

# %%
len(rep_study_df)
# Out:
# 159

# %%
sum(members["republican study committee"] == True)
# Out:
# 159

# %%
members
# Out:
#                          name         username republican study committee
# 0          Abigail Spanberger    RepSpanberger                        NaN
# 1              Adam Kinzinger     RepKinzinger                        NaN
# 2                 Adam Schiff    RepAdamSchiff                        NaN
# 3                  Adam Smith     RepAdamSmith                        NaN
# 4                Adrian Smith   RepAdrianSmith                        NaN
# 5           Adriano Espaillat     RepEspaillat                        NaN
# 6                    Al Green       RepAlGreen                        NaN
# 7                   Al Lawson    RepAlLawsonJr                        NaN
# 8              Alan Lowenthal     RepLowenthal                        NaN
# 9                 Albio Sires         RepSires                        NaN
# 10             Alcee Hastings    RepHastingsFL                        NaN
# 11                Alex Mooney    RepAlexMooney                       True
# 12               Alex Padilla   SenAlexPadilla                        NaN
# 13   Alexandria Ocasio-Cortez           RepAOC                        NaN
# 14                 Alma Adams         RepAdams                        NaN
# 15            Amata Radewagen         RepAmata                        NaN
# 16                   Ami Bera          RepBera                        NaN
# 17              Amy Klobuchar  SenAmyKlobuchar                        NaN
# 18               Andre Carson   RepAndreCarson                        NaN
# 19               Andrew Clyde        Rep_Clyde                       True
# 20           Andrew Garbarino     RepGarbarino                        NaN
# 21                  Andy Barr      RepAndyBarr                       True
# 22                 Andy Biggs   RepAndyBiggsAZ                        NaN
# 23                Andy Harris  RepAndyHarrisMD                        NaN
# 24                   Andy Kim     RepAndyKimNJ                        NaN
# 25                 Andy Levin     RepAndyLevin                        NaN
# 26                Angie Craig    RepAngieCraig                        NaN
# 27                 Angus King     SenAngusKing                        NaN
# 28            Ann Kirkpatrick   RepKirkpatrick                        NaN
# 29          Ann McLane Kuster   RepAnnieKuster                        NaN
# 30                 Ann Wagner     RepAnnWagner                       True
# 31                 Anna Eshoo     RepAnnaEshoo                        NaN
# 32              Anthony Brown  RepAnthonyBrown                        NaN
# 33           Anthony Gonzalez     RepAGonzalez                        NaN
# 34            Antonio Delgado       repdelgado                        NaN
# 35              Ashley Hinson  RepAshleyHinson                       True
# 36             August Pfluger       RepPfluger                       True
# 37               Austin Scott  AustinScottGA08                       True
# 38            Ayanna Pressley      RepPressley                        NaN
# 39                Barbara Lee    RepBarbaraLee                        NaN
# 40           Barry Loudermilk    RepLoudermilk                       True
# 41                Barry Moore    RepBarryMoore                       True
# 42                  Ben Cline      RepBenCline                       True
# 43                  Ben Lujan     SenatorLujan                        NaN
# 44                  Ben Sasse         SenSasse                        NaN
# 45            Benjamin Cardin    SenatorCardin                        NaN
# 46             Bernie Sanders       SenSanders                        NaN
# 47            Bernie Thompson  BennieGThompson                        NaN
# 48             Beth Van Duyne  RepBethVanDuyne                       True
# 49             Betty McCollum  BettyMcCollum04                        NaN
# 50               Bill Cassidy   SenBillCassidy                        NaN
# 51                Bill Foster    RepBillFoster                        NaN
# 52               Bill Hagerty   SenatorHagerty                        NaN
# 53              Bill Huizenga      RepHuizenga                       True
# 54               Bill Johnson   RepBillJohnson                       True
# 55               Bill Keating     USRepKeating                        NaN
# 56              Bill Pascrell     BillPascrell                        NaN
# 57                 Bill Posey    congbillposey                       True
# 58                 Billy Long        USRepLong                        NaN
# 59         Blaine Luetkemeyer        RepBlaine                       True
# 60                Blake Moore    RepBlakeMoore                       True
# 61                  Bob Gibbs      RepBobGibbs                       True
# 62                   Bob Good       RepBobGood                       True
# 63               Bob Menendez  SenatorMenendez                        NaN
# 64                 Bobby Rush     RepBobbyRush                        NaN
# 65      Bonnie Watson Coleman        RepBonnie                        NaN
# 66             Brad Schneider     RepSchneider                        NaN
# 67               Brad Sherman      BradSherman                        NaN
# 68              Brad Wenstrup  RepBradWenstrup                       True
# 69            Brenda Lawrence      RepLawrence                        NaN
# 70              Brendan Boyle        CongBoyle                        NaN
# 71              Brett Guthrie       RepGuthrie                       True
# 72                Brian Babin    RepBrianBabin                       True
# 73          Brian Fitzpatrick     RepBrianFitz                        NaN
# 74              Brian Higgins  RepBrianHiggins                        NaN
# 75                 Brian Mast     RepBrianMast                       True
# 76               Brian Schatz   SenBrianSchatz                        NaN
# 77            Bruce Westerman     RepWesterman                       True
# 78                Bryan Steil    RepBryanSteil                       True
# 79               Buddy Carter   RepBuddyCarter                       True
# 80              Burgess Owens  RepBurgessOwens                       True
# 81              Byron Donalds  RepDonaldsPress                       True
# 82             Carlos Gimenez        RepCarlos                       True
# 83               Carol Miller   RepCarolMiller                        NaN
# 84          Carolyn Bourdeaux     RepBourdeaux                        NaN
# 85            Carolyn Maloney       RepMaloney                        NaN
# 86     Catherine Cortez Masto   SenCortezMasto                        NaN
# 87     Cathy McMorris Rodgers    cathymcmorris                       True
# 88            Charles Schumer       SenSchumer                        NaN
# 89              Charlie Crist  RepCharlieCrist                        NaN
# 90            Chellie Pingree   chelliepingree                        NaN
# 91               Cheri Bustos         RepCheri                        NaN
# 92                   Chip Roy       RepChipRoy                       True
# 93               Chris Jacobs        RepJacobs                       True
# 94               Chris Pappas   RepChrisPappas                        NaN
# 95                Chris Smith              NaN                        NaN
# 96              Chris Stewart  RepChrisStewart                       True
# 97           Chris Van Hollen   ChrisVanHollen                        NaN
# 98           Chrissy Houlahan      RepHoulahan                        NaN
# 99          Christopher Coons       ChrisCoons                        NaN
# 100        Christopher Murphy    ChrisMurphyCT                        NaN
# 101         Chuck Fleischmann         RepChuck                       True
# 102            Chuck Grassley    ChuckGrassley                        NaN
# 103                Cindy Axne     RepCindyAxne                        NaN
# 104          Cindy Hyde-Smith     SenHydeSmith                        NaN
# 105            Claudia Tenney              NaN                       True
# 106              Clay Higgins   RepClayHiggins                       True
# 107               Cliff Bentz         RepBentz                       True
# 108              Colin Allred   RepColinAllred                        NaN
# 109                Conor Lamb     RepConorLamb                        NaN
# 110                 Cori Bush          RepCori                        NaN
# 111               Cory Booker       CoryBooker                        NaN
# 112            Cynthia Lummis        SenLummis                        NaN
# 113                Dan Bishop     RepDanBishop                       True
# 114              Dan Crenshaw   RepDanCrenshaw                       True
# 115                Dan Kildee     RepDanKildee                        NaN
# 116              Dan Newhouse      RepNewhouse                       True
# 117              Dan Sullivan   SenDanSullivan                        NaN
# 118             Daniel Meuser        RepMeuser                       True
# 119            Daniel Webster       RepWebster                       True
# 120               Danny Davis    RepDannyDavis                        NaN
# 121              Darin LaHood        RepLaHood                       True
# 122              Darrell Issa   repdarrellissa                       True
# 123               Darren Soto    RepDarrenSoto                        NaN
# 124           David Cicilline     RepCicilline                        NaN
# 125               David Joyce     RepDaveJoyce                        NaN
# 126             David Kustoff  RepDavidKustoff                       True
# 127            David McKinley      RepMcKinley                       True
# 128               David Price   RepDavidEPrice                        NaN
# 129              David Rouzer   RepDavidRouzer                       True
# 130          David Schweikert         RepDavid                       True
# 131               David Scott    repdavidscott                        NaN
# 132               David Trone    RepDavidTrone                        NaN
# 133             David Valadao  RepDavidValadao                        NaN
# 134             Dean Phillips  RepDeanPhillips                        NaN
# 135               Deb Fischer   SenatorFischer                        NaN
# 136            Debbie Dingell    RepDebDingell                        NaN
# 137              Debbie Lesko        RepDLesko                       True
# 138           Debbie Stabenow      SenStabenow                        NaN
# 139  Debbie Wasserman Schultz     RepDWStweets                        NaN
# 140              Deborah Ross   RepDeborahRoss                        NaN
# 141             Debra Haaland    RepDebHaaland                        NaN
# 142              Derek Kilmer   RepDerekKilmer                        NaN
# 143               Devin Nunes    RepDevinNunes                        NaN
# 144             Diana DeGette  RepDianaDeGette                        NaN
# 145         Diana Harshbarger   RepHarshbarger                       True
# 146          Dianne Feinstein     SenFeinstein                        NaN
# 147                Dina Titus     repdinatitus                        NaN
# 148                 Don Bacon      RepDonBacon                       True
# 149                 Don Beyer      RepDonBeyer                        NaN
# 150                 Don Young      repdonyoung                        NaN
# 151           Donald McEachin      RepMcEachin                        NaN
# 152           Donald Norcross   DonaldNorcross                        NaN
# 153              Donald Payne   RepDonaldPayne                        NaN
# 154              Doris Matsui      DorisMatsui                        NaN
# 155              Doug LaMalfa       RepLaMalfa                       True
# 156              Doug Lamborn      RepDLamborn                       True
# 157             Drew Ferguson  RepDrewFerguson                       True
# 158             Dusty Johnson  RepDustyJohnson                       True
# 159       Dutch Ruppersberger    Call_Me_Dutch                        NaN
# 160              Dwight Evans   RepDwightEvans                        NaN
# 161           Earl Blumenauer    repblumenauer                        NaN
# 162                   Ed Case        RepEdCase                        NaN
# 163             Ed Perlmutter    RepPerlmutter                        NaN
# 164     Eddie Bernice Johnson           RepEBJ                        NaN
# 165             Edward Markey        SenMarkey                        NaN
# 166              Elaine Luria   RepElaineLuria                        NaN
# 167     Eleanor Holmes Norton    EleanorNorton                        NaN
# 168            Elise Stefanik      RepStefanik                       True
# 169            Elissa Slotkin       RepSlotkin                        NaN
# 170          Elizabeth Warren        SenWarren                        NaN
# 171           Emanuel Cleaver       repcleaver                        NaN
# 172             Eric Swalwell      RepSwalwell                        NaN
# 173              Filemon Vela   RepFilemonVela                        NaN
# 174               Frank Lucas    RepFrankLucas                        NaN
# 175               Frank Mrvan         RepMrvan                        NaN
# 176             Frank Pallone     FrankPallone                        NaN
# 177               Fred Keller    RepFredKeller                       True
# 178                Fred Upton     RepFredUpton                        NaN
# 179          Frederica Wilson        RepWilson                        NaN
# 180               French Hill    RepFrenchHill                       True
# 181          G.K. Butterfield    GKButterfield                        NaN
# 182             Garret Graves  RepGarretGraves                       True
# 183               Gary Palmer  USRepGaryPalmer                       True
# 184               Gary Peters    SenGaryPeters                        NaN
# 185            Gerry Connolly            Gerry                        NaN
# 186            Glenn Grothman      RepGrothman                       True
# 187            Glenn Thompson    CongressmanGT                        NaN
# 188                Grace Meng     RepGraceMeng                        NaN
# 189          Grace Napolitano  gracenapolitano                        NaN
# 190                Greg Pence     RepGregPence                        NaN
# 191              Greg Stanton   RepGregStanton                        NaN
# 192               Greg Steube    RepGregSteube                       True
# 193           Gregorio Sablan    Kilili_Sablan                        NaN
# 194             Gregory Meeks  RepGregoryMeeks                        NaN
# 195            Gregory Murphy    RepGregMurphy                       True
# 196             Gus Bilirakis  RepGusBilirakis                       True
# 197         Guy Reschenthaler   GReschenthaler                       True
# 198                Gwen Moore     RepGwenMoore                        NaN
# 199           Hakeem Jeffries      RepJeffries                        NaN
# 200             Haley Stevens  RepHaleyStevens                        NaN
# 201             Harold Rogers     RepHalRogers                        NaN
# 202             Henry Cuellar       RepCuellar                        NaN
# 203             Henry Johnson   RepHankJohnson                        NaN
# 204                Ilhan Omar            Ilhan                        NaN
# 205              Jack Bergman   RepJackBergman                       True
# 206                 Jack Reed      SenJackReed                        NaN
# 207             Jackie Speier        RepSpeier                        NaN
# 208           Jackie Walorski      RepWalorski                       True
# 209               Jacky Rosen    SenJackyRosen                        NaN
# 210              Jahana Hayes   RepJahanaHayes                        NaN
# 211     Jaime Herrera Beutler   HerreraBeutler                        NaN
# 212          Jake Auchincloss   RepAuchincloss                        NaN
# 213             Jake LaTurner      RepLaTurner                       True
# 214             Jamaal Bowman        RepBowman                        NaN
# 215             James Clyburn      WhipClyburn                        NaN
# 216               James Comer    RepJamesComer                       True
# 217              James Inhofe        JimInhofe                        NaN
# 218            James Lankford  SenatorLankford                        NaN
# 219            James McGovern      RepMcGovern                        NaN
# 220               James Risch     SenatorRisch                        NaN
# 221              Jamie Raskin        RepRaskin                        NaN
# 222            Jan Schakowsky    janschakowsky                        NaN
# 223              Jared Golden        RepGolden                        NaN
# 224             Jared Huffman       RepHuffman                        NaN
# 225                Jason Crow     RepJasonCrow                        NaN
# 226               Jason Smith    RepJasonSmith                       True
# 227             Jay Obernolte     JayObernolte                       True
# 228            Jeanne Shaheen   SenatorShaheen                        NaN
# 229               Jeff Duncan    RepJeffDuncan                       True
# 230          Jeff Fortenberry  JeffFortenberry                        NaN
# 231              Jeff Merkley   SenJeffMerkley                        NaN
# 232        Jefferson Van Drew              NaN                        NaN
# 233           Jennifer Wexton        RepWexton                        NaN
# 234  Jenniffer Gonzalez-Colon     RepJenniffer                        NaN
# 235            Jerrold Nadler   RepJerryNadler                        NaN
# 236                Jerry Carl     RepJerryCarl                       True
# 237            Jerry McNerney      RepMcNerney                        NaN
# 238               Jerry Moran       JerryMoran                        NaN
# 239              Jesus Garcia    RepChuyGarcia                        NaN
# 240                 Jim Baird      RepJimBaird                       True
# 241                 Jim Banks      RepJimBanks                       True
# 242                Jim Cooper     repjimcooper                        NaN
# 243                 Jim Costa      RepJimCosta                        NaN
# 244              Jim Hagedorn      RepHagedorn                        NaN
# 245                 Jim Himes          jahimes                        NaN
# 246                Jim Jordan       Jim_Jordan                        NaN
# 247              Jim Langevin      JimLangevin                        NaN
# 248               Jimmy Gomez    RepJimmyGomez                        NaN
# 249             Jimmy Panetta  RepJimmyPanetta                        NaN
# 250            Joaquin Castro  JoaquinCastrotx                        NaN
# 251           Jodey Arrington     RepArrington                       True
# 252                 Jody Hice  CongressmanHice                       True
# 253              Joe Courtney   RepJoeCourtney                        NaN
# 254               Joe Manchin   Sen_JoeManchin                        NaN
# 255               Joe Morelle    RepJoeMorelle                        NaN
# 256                Joe Neguse     RepJoeNeguse                        NaN
# 257                Joe Wilson     RepJoeWilson                       True
# 258             John Barrasso  SenJohnBarrasso                        NaN
# 259              John Boozman      JohnBoozman                        NaN
# 260               John Carter      JudgeCarter                       True
# 261               John Cornyn       JohnCornyn                        NaN
# 262               John Curtis    RepJohnCurtis                       True
# 263            John Garamendi     RepGaramendi                        NaN
# 264         John Hickenlooper      SenatorHick                        NaN
# 265               John Hoeven    SenJohnHoeven                        NaN
# 266                John Joyce     RepJohnJoyce                       True
# 267                John Katko     RepJohnKatko                        NaN
# 268              John Kennedy   SenJohnKennedy                        NaN
# 269               John Larson    RepJohnLarson                        NaN
# 270            John Moolenaar     RepMoolenaar                       True
# 271                 John Rose      RepJohnRose                       True
# 272           John Rutherford  RepRutherfordFL                        NaN
# 273             John Sarbanes      RepSarbanes                        NaN
# 274                John Thune     SenJohnThune                        NaN
# 275              John Yarmuth   RepJohnYarmuth                        NaN
# 276                Jon Ossoff           ossoff                        NaN
# 277                Jon Tester    SenatorTester                        NaN
# 278                Joni Ernst     SenJoniErnst                        NaN
# 279           Josh Gottheimer         RepJoshG                        NaN
# 280               Josh Harder    RepJoshHarder                        NaN
# 281               Josh Hawley         HawleyMO                        NaN
# 282              Joyce Beatty        RepBeatty                        NaN
# 283               Juan Vargas    RepJuanVargas                        NaN
# 284                  Judy Chu       RepJudyChu                        NaN
# 285            Julia Brownley      RepBrownley                        NaN
# 286              Julia Letlow              NaN                       True
# 287                Kai Kahele        KaheleRep                        NaN
# 288                Karen Bass     RepKarenBass                        NaN
# 289               Kat Cammack    RepKatCammack                       True
# 290           Katherine Clark        RepKClark                        NaN
# 291             Kathleen Rice  RepKathleenRice                        NaN
# 292              Kathy Castor     USRepKCastor                        NaN
# 293             Kathy Manning      RepKManning                        NaN
# 294              Katie Porter   RepKatiePorter                        NaN
# 295               Kay Granger    RepKayGranger                       True
# 296           Kelly Armstrong   RepArmstrongND                       True
# 297                  Ken Buck       RepKenBuck                       True
# 298               Ken Calvert       KenCalvert                        NaN
# 299               Kevin Brady    RepKevinBrady                       True
# 300              Kevin Cramer   SenKevinCramer                        NaN
# 301                Kevin Hern     repkevinhern                       True
# 302            Kevin McCarthy        GOPLeader                        NaN
# 303               Kim Schrier    RepKimSchrier                        NaN
# 304        Kirsten Gillibrand    SenGillibrand                        NaN
# 305             Kurt Schrader      RepSchrader                        NaN
# 306              Kweisi Mfume   RepKweisiMfume                        NaN
# 307            Kyrsten Sinema    SenatorSinema                        NaN
# 308              Lance Gooden      Lancegooden                       True
# 309             Larry Bucshon  RepLarryBucshon                       True
# 310            Lauren Boebert       RepBoebert                       True
# 311          Lauren Underwood     RepUnderwood                        NaN
# 312                Lee Zeldin     RepLeeZeldin                        NaN
# 313             Linda Sanchez  RepLindaSanchez                        NaN
# 314            Lindsey Graham  LindseyGrahamSC                        NaN
# 315      Lisa Blunt Rochester           RepLBR                        NaN
# 316              Lisa McClain   RepLisaMcClain                       True
# 317            Lisa Murkowski    lisamurkowski                        NaN
# 318                Liz Cheney     RepLizCheney                        NaN
# 319           Lizzie Fletcher      RepFletcher                        NaN
# 320             Lloyd Doggett  RepLloydDoggett                        NaN
# 321             Lloyd Smucker       RepSmucker                       True
# 322              Lois Frankel   RepLoisFrankel                        NaN
# 323               Lori Trahan    RepLoriTrahan                        NaN
# 324                Lou Correa     RepLouCorrea                        NaN
# 325             Louie Gohmert  replouiegohmert                        NaN
# 326     Lucille Roybal-Allard  RepRoybalAllard                        NaN
# 327               Lucy McBath    RepLucyMcBath                        NaN
# 328            Madeleine Dean          RepDean                        NaN
# 329          Madison Cawthorn      RepCawthorn                       True
# 330               Marc Veasey        RepVeasey                        NaN
# 331              Marcia Fudge   RepMarciaFudge                        NaN
# 332               Marco Rubio       marcorubio                        NaN
# 333              Marcy Kaptur   RepMarcyKaptur                        NaN
# 334           Margaret Hassan    SenatorHassan                        NaN
# 335            Maria Cantwell  SenatorCantwell                        NaN
# 336             Maria Salazar  RepMariaSalazar                        NaN
# 337  Mariannette Miller-Meeks           RepMMM                        NaN
# 338              Marie Newman   RepMarieNewman                        NaN
# 339        Marilyn Strickland  RepStricklandWA                        NaN
# 340         Mario Diaz-Balart          MarioDB                        NaN
# 341    Marjorie Taylor Greene           RepMTG                       True
# 342               Mark Amodei    MarkAmodeiNV2                        NaN
# 343           Mark DeSaulnier    RepDeSaulnier                        NaN
# 344                Mark Green     RepMarkGreen                       True
# 345                Mark Kelly     SenMarkKelly                        NaN
# 346                Mark Pocan     repmarkpocan                        NaN
# 347               Mark Takano    RepMarkTakano                        NaN
# 348               Mark Warner       MarkWarner                        NaN
# 349          Markwayne Mullin        RepMullin                       True
# 350          Marsha Blackburn  MarshaBlackburn                        NaN
# 351           Martin Heinrich   MartinHeinrich                        NaN
# 352          Mary Gay Scanlon           RepMGS                        NaN
# 353               Mary Miller    RepMaryMiller                       True
# 354           Matt Cartwright    RepCartwright                        NaN
# 355                Matt Gaetz     RepMattGaetz                        NaN
# 356         Matthew Rosendale     RepRosendale                       True
# 357             Maxine Waters  RepMaxineWaters                        NaN
# 358              Mazie Hirono      maziehirono                        NaN
# 359            Michael Bennet    SenatorBennet                        NaN
# 360           Michael Burgess  michaelcburgess                       True
# 361             Michael Cloud       RepCloudTX                       True
# 362             Michael Doyle   USRepMikeDoyle                        NaN
# 363             Michael Guest  RepMichaelGuest                        NaN
# 364            Michael McCaul        RepMcCaul                       True
# 365       Michael San Nicolas  GuamCongressman                        NaN
# 366             Michael Waltz    michaelgwaltz                       True
# 367        Michelle Fischbach     RepFischbach                       True
# 368            Michelle Steel         RepSteel                        NaN
# 369                 Mike Bost          RepBost                       True
# 370                Mike Braun     SenatorBraun                        NaN
# 371                Mike Carey              NaN                       True
# 372                Mike Crapo        MikeCrapo                        NaN
# 373            Mike Gallagher     RepGallagher                       True
# 374               Mike Garcia    RepMikeGarcia                       True
# 375              Mike Johnson   RepMikeJohnson                       True
# 376                Mike Kelly      MikeKellyPA                       True
# 377                  Mike Lee       SenMikeLee                        NaN
# 378                Mike Levin     RepMikeLevin                        NaN
# 379              Mike Quigley   RepMikeQuigley                        NaN
# 380               Mike Rogers  RepMikeRogersAL                       True
# 381               Mike Rounds    SenatorRounds                        NaN
# 382              Mike Simpson  CongMikeSimpson                        NaN
# 383             Mike Thompson      RepThompson                        NaN
# 384               Mike Turner    RepMikeTurner                       True
# 385            Mikie Sherrill      RepSherrill                        NaN
# 386           Mitch McConnell     senatemajldr                        NaN
# 387               Mitt Romney    SenatorRomney                        NaN
# 388                 Mo Brooks      RepMoBrooks                        NaN
# 389            Mondaire Jones      RepMondaire                        NaN
# 390           Morgan Griffith     RepMGriffith                        NaN
# 391                Nancy Mace     RepNancyMace                        NaN
# 392              Nancy Pelosi    SpeakerPelosi                        NaN
# 393          Nanette Barragan      RepBarragan                        NaN
# 394                 Neal Dunn    DrNealDunnFL2                       True
# 395        Nicole Malliotakis   RepMalliotakis                       True
# 396           Nikema Williams        RepNikema                        NaN
# 397              Norma Torres     NormaJTorres                        NaN
# 398           Nydia Velazquez   NydiaVelazquez                        NaN
# 399                Pat Fallon     RepPatFallon                       True
# 400             Patrick Leahy     SenatorLeahy                        NaN
# 401           Patrick McHenry   PatrickMcHenry                       True
# 402            Patrick Toomey        SenToomey                        NaN
# 403             Patty Murrary      PattyMurray                        NaN
# 404                Paul Gosar         RepGosar                       True
# 405                Paul Tonko     RepPaulTonko                        NaN
# 406              Pete Aguilar   RepPeteAguilar                        NaN
# 407             Pete Sessions     PeteSessions                        NaN
# 408              Pete Stauber   RepPeteStauber                       True
# 409             Peter DeFazio  RepPeterDeFazio                        NaN
# 410              Peter Meijer        RepMeijer                        NaN
# 411               Peter Welch       PeterWelch                        NaN
# 412           Pramila Jayapal       RepJayapal                        NaN
# 413       Raja Krishnamoorthi  CongressmanRaja                        NaN
# 414              Ralph Norman   RepRalphNorman                       True
# 415                 Rand Paul         RandPaul                        NaN
# 416            Randy Feenstra      RepFeenstra                       True
# 417               Randy Weber        TXRandy14                       True
# 418           Raphael Warnock   SenatorWarnock                        NaN
# 419             Rashida Tlaib       RepRashida                        NaN
# 420             Raul Grijalva  RepRaulGrijalva                        NaN
# 421                 Raul Ruiz    RepRaulRuizMD                        NaN
# 422        Richard Blumenthal    SenBlumenthal                        NaN
# 423              Richard Burr      SenatorBurr                        NaN
# 424            Richard Durbin    SenatorDurbin                        NaN
# 425            Richard Hudson    RepRichHudson                       True
# 426              Richard Neal   RepRichardNeal                        NaN
# 427            Richard Shelby        SenShelby                        NaN
# 428                Rick Allen     RepRickAllen                       True
# 429             Rick Crawford  RepRickCrawford                        NaN
# 430               Rick Larsen    RepRickLarsen                        NaN
# 431                Rick Scott     SenRickScott                        NaN
# 432            Ritchie Torres       RepRitchie                        NaN
# 433                 Ro Khanna      RepRoKhanna                        NaN
# 434               Rob Portman    senrobportman                        NaN
# 435           Robert Aderholt  Robert_Aderholt                       True
# 436              Robert Casey      SenBobCasey                        NaN
# 437              Robert Latta         boblatta                       True
# 438              Robert Scott       BobbyScott                        NaN
# 439            Robert Wittman       RobWittman                       True
# 440               Robin Kelly    RepRobinKelly                        NaN
# 441              Rodney Davis      RodneyDavis                        NaN
# 442            Roger Marshall  SenatorMarshall                        NaN
# 443              Roger Wicker    SenatorWicker                        NaN
# 444            Roger Williams     RepRWilliams                       True
# 445                 Ron Estes      RepRonEstes                       True
# 446               Ron Johnson    SenRonJohnson                        NaN
# 447                  Ron Kind       RepRonKind                        NaN
# 448                Ron Wright     RepRonWright                        NaN
# 449                 Ron Wyden         RonWyden                        NaN
# 450             Ronny Jackson  RepRonnyJackson                       True
# 451              Rosa DeLauro      rosadelauro                        NaN
# 452                 Roy Blunt         RoyBlunt                        NaN
# 453             Ruben Gallego  RepRubenGallego                        NaN
# 454              Russ Fulcher   RepRussFulcher                       True
# 455            Salud Carbajal      RepCarbajal                        NaN
# 456                Sam Graves     RepSamGraves                        NaN
# 457        Sanford Bishop Jr.    SanfordBishop                        NaN
# 458               Sara Jacobs    RepSaraJacobs                        NaN
# 459          Scott DesJarlais   DesJarlaisTN04                       True
# 460          Scott Fitzgerald    RepFitzgerald                       True
# 461            Scott Franklin      RepFranklin                       True
# 462               Scott Perry    RepScottPerry                        NaN
# 463              Scott Peters   RepScottPeters                        NaN
# 464               Sean Casten        RepCasten                        NaN
# 465      Sean Patrick Maloney   RepSeanMaloney                        NaN
# 466              Seth Moulton      teammoulton                        NaN
# 467            Sharice Davids        RepDavids                        NaN
# 468        Sheila Jackson Lee   JacksonLeeTX18                        NaN
# 469        Sheldon Whitehouse    SenWhitehouse                        NaN
# 470            Shelley Capito        SenCapito                        NaN
# 471             Sherrod Brown  SenSherrodBrown                        NaN
# 472           Stacey Plaskett   StaceyPlaskett                        NaN
# 473               Steny Hoyer      LeaderHoyer                        NaN
# 474            Stephanie Bice          RepBice                        NaN
# 475          Stephanie Murphy   RepStephMurphy                        NaN
# 476             Stephen Lynch  RepStephenLynch                        NaN
# 477              Steve Chabot   RepSteveChabot                       True
# 478               Steve Cohen         RepCohen                        NaN
# 479              Steve Daines      SteveDaines                        NaN
# 480             Steve Scalise     SteveScalise                       True
# 481             Steve Stivers  RepSteveStivers                        NaN
# 482              Steve Womack  rep_stevewomack                        NaN
# 483           Steven Horsford      RepHorsford                        NaN
# 484            Steven Palazzo      CongPalazzo                       True
# 485             Susan Collins   SenatorCollins                        NaN
# 486                Susan Wild     RepSusanWild                        NaN
# 487                 Susie Lee      RepSusieLee                        NaN
# 488             Suzan DelBene       RepDelBene                        NaN
# 489          Suzanne Bonamici      RepBonamici                        NaN
# 490             Sylvia Garcia  RepSylviaGarcia                        NaN
# 491             Tammy Baldwin   SenatorBaldwin                        NaN
# 492           Tammy Duckworth     SenDuckworth                        NaN
# 493                  Ted Budd       RepTedBudd                       True
# 494                  Ted Cruz       SenTedCruz                        NaN
# 495                Ted Deutch     RepTedDeutch                        NaN
# 496                  Ted Lieu       RepTedLieu                        NaN
# 497    Teresa Leger Fernandez      RepTeresaLF                        NaN
# 498              Terri Sewell   RepTerriSewell                        NaN
# 499               Thom Tillis    SenThomTillis                        NaN
# 500             Thomas Carper    SenatorCarper                        NaN
# 501             Thomas Massie  RepThomasMassie                        NaN
# 502             Thomas Suozzi     RepTomSuozzi                        NaN
# 503            Thomas Tiffany       RepTiffany                       True
# 504              Tim Burchett   RepTimBurchett                       True
# 505                 Tim Kaine         timkaine                        NaN
# 506                  Tim Ryan       RepTimRyan                        NaN
# 507                 Tim Scott  SenatorTimScott                        NaN
# 508               Tim Walberg       RepWalberg                       True
# 509                Tina Smith     SenTinaSmith                        NaN
# 510                Todd Young     SenToddYoung                        NaN
# 511                  Tom Cole      TomColeOK04                       True
# 512                Tom Cotton     SenTomCotton                        NaN
# 513                 Tom Emmer      RepTomEmmer                       True
# 514            Tom Malinowski    RepMalinowski                        NaN
# 515            Tom McClintock    RepMcClintock                       True
# 516            Tom O'Halleran     RepOHalleran                        NaN
# 517                  Tom Reed       RepTomReed                       True
# 518                  Tom Rice       RepTomRice                       True
# 519          Tommy Tuberville    SenTuberville                        NaN
# 520             Tony Cardenas      RepCardenas                        NaN
# 521             Tony Gonzales  RepTonyGonzales                       True
# 522               Tracey Mann          RepMann                       True
# 523               Trent Kelly    RepTrentKelly                       True
# 524        Trey Hollingsworth          RepTrey                        NaN
# 525            Troy Balderson     RepBalderson                       True
# 526                Troy Nehls     RepTroyNehls                       True
# 527               Val Demings    RepValDemings                        NaN
# 528                Van Taylor     RepVanTaylor                       True
# 529             Vern Buchanan     VernBuchanan                       True
# 530          Veronica Escobar       RepEscobar                        NaN
# 531          Vicente Gonzalez      RepGonzalez                        NaN
# 532            Vicky Hartzler      RepHartzler                       True
# 533           Victoria Spartz        RepSpartz                       True
# 534             Virginia Foxx     virginiafoxx                       True
# 535           Warren Davidson   WarrenDavidson                       True
# 536           William Timmons       RepTimmons                       True
# 537                 Young Kim      RepYoungKim                        NaN
# 538             Yvette Clarke  RepYvetteClarke                        NaN
# 539            Yvette Herrell       RepHerrell                       True
# 540               Zoe Lofgren    RepZoeLofgren                        NaN
